# %% [markdown]
# <a href="https://colab.research.google.com/github/oktaviorezap/oktaviorezap/blob/main/OKTAVIO_REZA_PUTRA_TASK_5_DATA_ENGINEER_VIX_BTPNS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Background**
#
# A manager at a bank was bothered by
# more and more client abandoning their credit card service
# their credit card services.
#
# **Objective**
#
# They would appreciate it if someone
# can figure out the customer profile so that they can
# know which client are going to leave so that they can
# can proactively go to the customer to
# provide better service and change the decision of
# client in the opposite direction.

# %% [markdown]
# **Connect Google Colaboratory to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Library**

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest #feature selection
from sklearn.feature_selection import chi2
from sklearn.utils import resample #re-sampling
from sklearn.model_selection import train_test_split #data splitting
from sklearn.preprocessing import StandardScaler #normalize features

from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn.naive_bayes import GaussianNB #gaussian naive bayes
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier #decision tree
from sklearn.ensemble import RandomForestClassifier #random forest
from sklearn.ensemble import GradientBoostingClassifier #Gradient Boosting Classifier
from sklearn.metrics import confusion_matrix, classification_report 
from sklearn.metrics import roc_auc_score #roc score

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %% [markdown]
# **Import and Inspect Dataset**

# %%
#import dataset
df = pd.read_csv('/content/drive/MyDrive/data_master_customer.csv', delimiter=';')

#display dataset form
print('This dataset has %d rows dan %d columns.\n' % df.shape)

#display top 5 rows of the dataset
df.head()
# Out:
# This dataset has 10127 rows dan 23 columns.
#    CLIENTNUM  idstatus             status  Customer_Age  Gender  \
# 0  768805383         1  Existing Customer            45    Male
# 1  818770008         1  Existing Customer            49  Female
# 2  713982108         1  Existing Customer            51    Male
# 3  769911858         1  Existing Customer            40  Female
# 4  709106358         1  Existing Customer            40    Male
#
#    Dependent_count  Educationid Education_Level  Maritalid Marital_Status  \
# 0                3            1     High School          1        Married
# 1                5            2        Graduate          2         Single
# 2                3            2        Graduate          1        Married
# 3                4            1     High School          3        Unknown
# 4                3            3      Uneducated          1        Married
#
#   Income_Category  card_categoryid Card_Category  Months_on_book  \
# 0     $60K - $80K                1          Blue              39
# 1  Less than $40K                1          Blue              44
# 2    $80K - $120K                1          Blue              36
# 3  Less than $40K                1          Blue              34
# 4     $60K - $80K                1          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Trans_Amt  \
# 0         12691                  777            11914             1144
# 1          8256                  864             7392             1291
# 2          3418                    0             3418             1887
# 3          3313                 2517              796             1171
# 4          4716                    0             4716              816
#
#    Total_Trans_Ct  Avg_Utilization_Ratio
# 0              42                  0.061
# 1              33                  0.105
# 2              20                  0.000
# 3              20                  0.760
# 4              28                  0.000

# %%
df.info(max_cols=200, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   idstatus                  10127 non-null  int64
#  2   status                    10127 non-null  object
#  3   Customer_Age              10127 non-null  int64
#  4   Gender                    10127 non-null  object
#  5   Dependent_count           10127 non-null  int64
#  6   Educationid               10127 non-null  int64
#  7   Education_Level           10127 non-null  object
#  8   Maritalid                 10127 non-null  int64
#  9   Marital_Status            10127 non-null  object
#  10  Income_Category           10127 non-null  object
#  11  card_categoryid           10127 non-null  int64
#  12  Card_Category             10127 non-null  object
#  13  Months_on_book            10127 non-null  int64
#  14  Total_Relationship_Count  10127 non-null  int64
#  15  Months_Inactive_12_mon    10127 non-null  int64
#  16  Contacts_Count_12_mon     10127 non-null  int64
#  17  Credit_Limit              10127 non-null  int64
#  18  Total_Revolving_Bal       10127 non-null  int64
#  19  Avg_Open_To_Buy           10127 non-null  int64
#  20  Total_Trans_Amt           10127 non-null  int64
#  21  Total_Trans_Ct            10127 non-null  int64
#  22  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(1), int64(16), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **Distribution of Customer Status**

# %%
cust_status = df.groupby('status').agg(cnt_client=('CLIENTNUM','count')).reset_index()
cust_status.style.background_gradient(cmap='gnuplot2_r')
# Out:
# <style type="text/css">
# #T_905b3_row0_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_905b3_row1_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_905b3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >status</th>
#       <th class="col_heading level0 col1" >cnt_client</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_905b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_905b3_row0_col0" class="data row0 col0" >Attrited Customer</td>
#       <td id="T_905b3_row0_col1" class="data row0 col1" >1627</td>
#     </tr>
#     <tr>
#       <th id="T_905b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_905b3_row1_col0" class="data row1 col0" >Existing Customer</td>
#       <td id="T_905b3_row1_col1" class="data row1 col1" >8500</td>
#     </tr>
#   </tbody>
# </table>

# %%
cust_norm = df['status'].value_counts(normalize=True).mul(100).round(2).reset_index()
cust_norm.columns = ['status','distribution']
cust_norm.style.background_gradient(cmap='gnuplot2_r')
# Out:
# <style type="text/css">
# #T_c41f0_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c41f0_row1_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_c41f0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >status</th>
#       <th class="col_heading level0 col1" >distribution</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c41f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c41f0_row0_col0" class="data row0 col0" >Existing Customer</td>
#       <td id="T_c41f0_row0_col1" class="data row0 col1" >83.930000</td>
#     </tr>
#     <tr>
#       <th id="T_c41f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c41f0_row1_col0" class="data row1 col0" >Attrited Customer</td>
#       <td id="T_c41f0_row1_col1" class="data row1 col1" >16.070000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize = (12,6))

import textwrap
f = lambda x: textwrap.fill(x.get_text(), 10)

a = sns.countplot('status', data = df, palette = 'RdYlBu')

plt.xlabel('Status')
plt.ylabel('Count')
plt.title('The Distribution of Customer Status')
a.set_xticklabels(map(f, a.get_xticklabels()))
plt.tick_params(labelsize=9)

plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
labels = ['Existing Customer','Attrited Customer']
churn = df.status.value_counts()
ax.pie(churn, labels=labels, autopct= '%.0f%%')
plt.title(label = 'The Distribution of Customer Status',
          size = 15,
          color = 'orange')
plt.show()

# %% [markdown]
# From the distribution of customer status, we know that :
# *   **There are 8500 Existing Customer that still use credit card service and 1627 Attrited Customer**
# *   **There are 84% Existing Customer that still use credit card service and 16% did not use credit card service anymore (Attrited Customer)**
#
# Notes: Attrited client are the group of client that has been lost through time for any reason. The process of losing a client is referred to as customer attrition, also known as customer churn.

# %% [markdown]
# ## **Data Visualization of Customer Status**

# %% [markdown]
# Distribution of Customer Status by:
# *   Gender
# *   Marital Status
# *   Education Level
# *   Income Type
# *   Card Category

# %%
#Data Visualization of Customer Status
sns.set_style('whitegrid')
fig, ax = plt.subplots(2,2 , figsize=(25,25))
sns.set_context('paper', font_scale=1)

#Give Title
fig.suptitle('Credit Card Service Client Status',color = 'black', fontweight= 'bold',fontsize = 15)

ax[0][0].set_title('Clients Status By Gender', fontweight='bold', fontsize=14, color='black')
sns.countplot(x='Gender', data = df, hue = 'status', palette = 'mako', ax=ax[0][0])

ax[0][1].set_title('Clients Status By Marital Status', fontweight='bold', fontsize=14, color='black')
sns.countplot(x='Marital_Status', data = df, hue = 'status', palette = 'mako', ax=ax[0][1])

ax[1][0].set_title('Clients Status By Education Level', fontweight='bold', fontsize=14, color='black')
sns.countplot(x='Education_Level', data = df, hue = 'status', palette = 'mako', ax=ax[1][0])

ax[1][1].set_title('Clients Status By Income Type', fontweight='bold', fontsize=14, color='black')
sns.countplot(x='Income_Category', data = df, hue = 'status', palette = 'mako', ax=ax[1][1])

# %%
#Data Visualization of Customer Status
plt.figure(figsize=(15,8))
fig = sns.countplot(x='Card_Category', data = df, hue = 'status', palette = 'mako')
plt.title('Clients Status by Category Card', fontweight='bold', fontsize=14, color='black')
plt.xlabel('\nCard Category', fontsize=12)
# Out:
# Text(0.5, 0, '\nCard Category')

# %%
 #Client Status by Gender
df_gender = df.groupby(by=['Gender','status']).agg(cnt_client=('CLIENTNUM','count')).sort_values(by=['Gender','status'],ascending=True).reset_index()
df_gender['percentage'] = 100 * df_gender['cnt_client'] / df_gender.groupby('Gender')['cnt_client'].transform('sum')
df_gender.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_e7dea_row0_col2 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_e7dea_row0_col3 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_e7dea_row1_col2, #T_e7dea_row3_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e7dea_row1_col3 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_e7dea_row2_col2, #T_e7dea_row2_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_e7dea_row3_col2 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7dea_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gender</th>
#       <th class="col_heading level0 col1" >status</th>
#       <th class="col_heading level0 col2" >cnt_client</th>
#       <th class="col_heading level0 col3" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7dea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7dea_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_e7dea_row0_col1" class="data row0 col1" >Attrited Customer</td>
#       <td id="T_e7dea_row0_col2" class="data row0 col2" >930</td>
#       <td id="T_e7dea_row0_col3" class="data row0 col3" >17.357223</td>
#     </tr>
#     <tr>
#       <th id="T_e7dea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7dea_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_e7dea_row1_col1" class="data row1 col1" >Existing Customer</td>
#       <td id="T_e7dea_row1_col2" class="data row1 col2" >4428</td>
#       <td id="T_e7dea_row1_col3" class="data row1 col3" >82.642777</td>
#     </tr>
#     <tr>
#       <th id="T_e7dea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7dea_row2_col0" class="data row2 col0" >Male</td>
#       <td id="T_e7dea_row2_col1" class="data row2 col1" >Attrited Customer</td>
#       <td id="T_e7dea_row2_col2" class="data row2 col2" >697</td>
#       <td id="T_e7dea_row2_col3" class="data row2 col3" >14.615223</td>
#     </tr>
#     <tr>
#       <th id="T_e7dea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7dea_row3_col0" class="data row3 col0" >Male</td>
#       <td id="T_e7dea_row3_col1" class="data row3 col1" >Existing Customer</td>
#       <td id="T_e7dea_row3_col2" class="data row3 col2" >4072</td>
#       <td id="T_e7dea_row3_col3" class="data row3 col3" >85.384777</td>
#     </tr>
#   </tbody>
# </table>

# %%
 #Client Status by Marital Status
df_marital = df.groupby(by=['Marital_Status','status']).agg(cnt_client=('CLIENTNUM','count')).sort_values(by=['Marital_Status','status'],ascending=True).reset_index()
df_marital['percentage'] = 100 * df_marital['cnt_client'] / df_marital.groupby('Marital_Status')['cnt_client'].transform('sum')
df_marital.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_6b15e_row0_col2, #T_6b15e_row2_col3, #T_6b15e_row6_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_6b15e_row0_col3 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_6b15e_row1_col2, #T_6b15e_row7_col2 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_6b15e_row1_col3 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_6b15e_row2_col2 {
#   background-color: #dff3f5;
#   color: #000000;
# }
# #T_6b15e_row3_col2, #T_6b15e_row3_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_6b15e_row4_col2 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_6b15e_row4_col3 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_6b15e_row5_col2 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_6b15e_row5_col3 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_6b15e_row6_col3 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_6b15e_row7_col3 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6b15e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Marital_Status</th>
#       <th class="col_heading level0 col1" >status</th>
#       <th class="col_heading level0 col2" >cnt_client</th>
#       <th class="col_heading level0 col3" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b15e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b15e_row0_col0" class="data row0 col0" >Divorced</td>
#       <td id="T_6b15e_row0_col1" class="data row0 col1" >Attrited Customer</td>
#       <td id="T_6b15e_row0_col2" class="data row0 col2" >121</td>
#       <td id="T_6b15e_row0_col3" class="data row0 col3" >16.176471</td>
#     </tr>
#     <tr>
#       <th id="T_6b15e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b15e_row1_col0" class="data row1 col0" >Divorced</td>
#       <td id="T_6b15e_row1_col1" class="data row1 col1" >Existing Customer</td>
#       <td id="T_6b15e_row1_col2" class="data row1 col2" >627</td>
#       <td id="T_6b15e_row1_col3" class="data row1 col3" >83.823529</td>
#     </tr>
#     <tr>
#       <th id="T_6b15e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b15e_row2_col0" class="data row2 col0" >Married</td>
#       <td id="T_6b15e_row2_col1" class="data row2 col1" >Attrited Customer</td>
#       <td id="T_6b15e_row2_col2" class="data row2 col2" >709</td>
#       <td id="T_6b15e_row2_col3" class="data row2 col3" >15.126947</td>
#     </tr>
#     <tr>
#       <th id="T_6b15e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b15e_row3_col0" class="data row3 col0" >Married</td>
#       <td id="T_6b15e_row3_col1" class="data row3 col1" >Existing Customer</td>
#       <td id="T_6b15e_row3_col2" class="data row3 col2" >3978</td>
#       <td id="T_6b15e_row3_col3" class="data row3 col3" >84.873053</td>
#     </tr>
#     <tr>
#       <th id="T_6b15e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b15e_row4_col0" class="data row4 col0" >Single</td>
#       <td id="T_6b15e_row4_col1" class="data row4 col1" >Attrited Customer</td>
#       <td id="T_6b15e_row4_col2" class="data row4 col2" >668</td>
#       <td id="T_6b15e_row4_col3" class="data row4 col3" >16.941415</td>
#     </tr>
#     <tr>
#       <th id="T_6b15e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b15e_row5_col0" class="data row5 col0" >Single</td>
#       <td id="T_6b15e_row5_col1" class="data row5 col1" >Existing Customer</td>
#       <td id="T_6b15e_row5_col2" class="data row5 col2" >3275</td>
#       <td id="T_6b15e_row5_col3" class="data row5 col3" >83.058585</td>
#     </tr>
#     <tr>
#       <th id="T_6b15e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b15e_row6_col0" class="data row6 col0" >Unknown</td>
#       <td id="T_6b15e_row6_col1" class="data row6 col1" >Attrited Customer</td>
#       <td id="T_6b15e_row6_col2" class="data row6 col2" >129</td>
#       <td id="T_6b15e_row6_col3" class="data row6 col3" >17.222964</td>
#     </tr>
#     <tr>
#       <th id="T_6b15e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6b15e_row7_col0" class="data row7 col0" >Unknown</td>
#       <td id="T_6b15e_row7_col1" class="data row7 col1" >Existing Customer</td>
#       <td id="T_6b15e_row7_col2" class="data row7 col2" >620</td>
#       <td id="T_6b15e_row7_col3" class="data row7 col3" >82.777036</td>
#     </tr>
#   </tbody>
# </table>

# %%
 #Client Status by Education Level
df_education = df.groupby(by=['Education_Level','status']).agg(cnt_client=('CLIENTNUM','count')).sort_values(by=['Education_Level','status'],ascending=True).reset_index()
df_education['percentage'] = 100 * df_education['cnt_client'] / df_education.groupby('Education_Level')['cnt_client'].transform('sum')
df_education.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_2350d_row0_col2, #T_2350d_row12_col3 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_2350d_row0_col3, #T_2350d_row2_col2, #T_2350d_row6_col3, #T_2350d_row8_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_2350d_row1_col2 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# #T_2350d_row1_col3, #T_2350d_row5_col2, #T_2350d_row7_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2350d_row2_col3, #T_2350d_row6_col2 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_2350d_row3_col2 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_2350d_row3_col3 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_2350d_row4_col2 {
#   background-color: #dff3f5;
#   color: #000000;
# }
# #T_2350d_row4_col3, #T_2350d_row10_col3 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_2350d_row5_col3 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_2350d_row7_col2 {
#   background-color: #3fab72;
#   color: #f1f1f1;
# }
# #T_2350d_row8_col3 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_2350d_row9_col2 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_2350d_row9_col3 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_2350d_row10_col2 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_2350d_row11_col2 {
#   background-color: #78cab1;
#   color: #000000;
# }
# #T_2350d_row11_col3 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_2350d_row12_col2 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_2350d_row13_col2 {
#   background-color: #77c9b0;
#   color: #000000;
# }
# #T_2350d_row13_col3 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2350d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Education_Level</th>
#       <th class="col_heading level0 col1" >status</th>
#       <th class="col_heading level0 col2" >cnt_client</th>
#       <th class="col_heading level0 col3" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2350d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2350d_row0_col0" class="data row0 col0" >College</td>
#       <td id="T_2350d_row0_col1" class="data row0 col1" >Attrited Customer</td>
#       <td id="T_2350d_row0_col2" class="data row0 col2" >154</td>
#       <td id="T_2350d_row0_col3" class="data row0 col3" >15.202369</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2350d_row1_col0" class="data row1 col0" >College</td>
#       <td id="T_2350d_row1_col1" class="data row1 col1" >Existing Customer</td>
#       <td id="T_2350d_row1_col2" class="data row1 col2" >859</td>
#       <td id="T_2350d_row1_col3" class="data row1 col3" >84.797631</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2350d_row2_col0" class="data row2 col0" >Doctorate</td>
#       <td id="T_2350d_row2_col1" class="data row2 col1" >Attrited Customer</td>
#       <td id="T_2350d_row2_col2" class="data row2 col2" >95</td>
#       <td id="T_2350d_row2_col3" class="data row2 col3" >21.064302</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2350d_row3_col0" class="data row3 col0" >Doctorate</td>
#       <td id="T_2350d_row3_col1" class="data row3 col1" >Existing Customer</td>
#       <td id="T_2350d_row3_col2" class="data row3 col2" >356</td>
#       <td id="T_2350d_row3_col3" class="data row3 col3" >78.935698</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2350d_row4_col0" class="data row4 col0" >Graduate</td>
#       <td id="T_2350d_row4_col1" class="data row4 col1" >Attrited Customer</td>
#       <td id="T_2350d_row4_col2" class="data row4 col2" >487</td>
#       <td id="T_2350d_row4_col3" class="data row4 col3" >15.569054</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2350d_row5_col0" class="data row5 col0" >Graduate</td>
#       <td id="T_2350d_row5_col1" class="data row5 col1" >Existing Customer</td>
#       <td id="T_2350d_row5_col2" class="data row5 col2" >2641</td>
#       <td id="T_2350d_row5_col3" class="data row5 col3" >84.430946</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2350d_row6_col0" class="data row6 col0" >High School</td>
#       <td id="T_2350d_row6_col1" class="data row6 col1" >Attrited Customer</td>
#       <td id="T_2350d_row6_col2" class="data row6 col2" >306</td>
#       <td id="T_2350d_row6_col3" class="data row6 col3" >15.201192</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2350d_row7_col0" class="data row7 col0" >High School</td>
#       <td id="T_2350d_row7_col1" class="data row7 col1" >Existing Customer</td>
#       <td id="T_2350d_row7_col2" class="data row7 col2" >1707</td>
#       <td id="T_2350d_row7_col3" class="data row7 col3" >84.798808</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2350d_row8_col0" class="data row8 col0" >Post-Graduate</td>
#       <td id="T_2350d_row8_col1" class="data row8 col1" >Attrited Customer</td>
#       <td id="T_2350d_row8_col2" class="data row8 col2" >92</td>
#       <td id="T_2350d_row8_col3" class="data row8 col3" >17.829457</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2350d_row9_col0" class="data row9 col0" >Post-Graduate</td>
#       <td id="T_2350d_row9_col1" class="data row9 col1" >Existing Customer</td>
#       <td id="T_2350d_row9_col2" class="data row9 col2" >424</td>
#       <td id="T_2350d_row9_col3" class="data row9 col3" >82.170543</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2350d_row10_col0" class="data row10 col0" >Uneducated</td>
#       <td id="T_2350d_row10_col1" class="data row10 col1" >Attrited Customer</td>
#       <td id="T_2350d_row10_col2" class="data row10 col2" >237</td>
#       <td id="T_2350d_row10_col3" class="data row10 col3" >15.938130</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2350d_row11_col0" class="data row11 col0" >Uneducated</td>
#       <td id="T_2350d_row11_col1" class="data row11 col1" >Existing Customer</td>
#       <td id="T_2350d_row11_col2" class="data row11 col2" >1250</td>
#       <td id="T_2350d_row11_col3" class="data row11 col3" >84.061870</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2350d_row12_col0" class="data row12 col0" >Unknown</td>
#       <td id="T_2350d_row12_col1" class="data row12 col1" >Attrited Customer</td>
#       <td id="T_2350d_row12_col2" class="data row12 col2" >256</td>
#       <td id="T_2350d_row12_col3" class="data row12 col3" >16.853193</td>
#     </tr>
#     <tr>
#       <th id="T_2350d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2350d_row13_col0" class="data row13 col0" >Unknown</td>
#       <td id="T_2350d_row13_col1" class="data row13 col1" >Existing Customer</td>
#       <td id="T_2350d_row13_col2" class="data row13 col2" >1263</td>
#       <td id="T_2350d_row13_col3" class="data row13 col3" >83.146807</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Client Status by Income Category (Type)
df_income = df.groupby(by=['Income_Category','status']).agg(cnt_client=('CLIENTNUM','count')).sort_values(by=['Income_Category','status'],ascending=True).reset_index()
df_income['percentage'] = 100 * df_income['cnt_client'] / df_income.groupby('Income_Category')['cnt_client'].transform('sum')
df_income.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_01157_row0_col2, #T_01157_row4_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_01157_row0_col3, #T_01157_row2_col2, #T_01157_row8_col3 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_01157_row1_col2 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_01157_row1_col3 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_01157_row2_col3, #T_01157_row4_col2, #T_01157_row10_col2 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_01157_row3_col2 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_01157_row3_col3 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_01157_row5_col2 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_01157_row5_col3, #T_01157_row9_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_01157_row6_col2, #T_01157_row10_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_01157_row6_col3 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_01157_row7_col2 {
#   background-color: #8ad2be;
#   color: #000000;
# }
# #T_01157_row7_col3 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_01157_row8_col2 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_01157_row9_col3 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_01157_row11_col2 {
#   background-color: #bfe7de;
#   color: #000000;
# }
# #T_01157_row11_col3 {
#   background-color: #005221;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_01157_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Income_Category</th>
#       <th class="col_heading level0 col1" >status</th>
#       <th class="col_heading level0 col2" >cnt_client</th>
#       <th class="col_heading level0 col3" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01157_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01157_row0_col0" class="data row0 col0" >$120K +</td>
#       <td id="T_01157_row0_col1" class="data row0 col1" >Attrited Customer</td>
#       <td id="T_01157_row0_col2" class="data row0 col2" >126</td>
#       <td id="T_01157_row0_col3" class="data row0 col3" >17.331499</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01157_row1_col0" class="data row1 col0" >$120K +</td>
#       <td id="T_01157_row1_col1" class="data row1 col1" >Existing Customer</td>
#       <td id="T_01157_row1_col2" class="data row1 col2" >601</td>
#       <td id="T_01157_row1_col3" class="data row1 col3" >82.668501</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01157_row2_col0" class="data row2 col0" >$40K - $60K</td>
#       <td id="T_01157_row2_col1" class="data row2 col1" >Attrited Customer</td>
#       <td id="T_01157_row2_col2" class="data row2 col2" >271</td>
#       <td id="T_01157_row2_col3" class="data row2 col3" >15.139665</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_01157_row3_col0" class="data row3 col0" >$40K - $60K</td>
#       <td id="T_01157_row3_col1" class="data row3 col1" >Existing Customer</td>
#       <td id="T_01157_row3_col2" class="data row3 col2" >1519</td>
#       <td id="T_01157_row3_col3" class="data row3 col3" >84.860335</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_01157_row4_col0" class="data row4 col0" >$60K - $80K</td>
#       <td id="T_01157_row4_col1" class="data row4 col1" >Attrited Customer</td>
#       <td id="T_01157_row4_col2" class="data row4 col2" >189</td>
#       <td id="T_01157_row4_col3" class="data row4 col3" >13.480742</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_01157_row5_col0" class="data row5 col0" >$60K - $80K</td>
#       <td id="T_01157_row5_col1" class="data row5 col1" >Existing Customer</td>
#       <td id="T_01157_row5_col2" class="data row5 col2" >1213</td>
#       <td id="T_01157_row5_col3" class="data row5 col3" >86.519258</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_01157_row6_col0" class="data row6 col0" >$80K - $120K</td>
#       <td id="T_01157_row6_col1" class="data row6 col1" >Attrited Customer</td>
#       <td id="T_01157_row6_col2" class="data row6 col2" >242</td>
#       <td id="T_01157_row6_col3" class="data row6 col3" >15.765472</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_01157_row7_col0" class="data row7 col0" >$80K - $120K</td>
#       <td id="T_01157_row7_col1" class="data row7 col1" >Existing Customer</td>
#       <td id="T_01157_row7_col2" class="data row7 col2" >1293</td>
#       <td id="T_01157_row7_col3" class="data row7 col3" >84.234528</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_01157_row8_col0" class="data row8 col0" >Less than $40K</td>
#       <td id="T_01157_row8_col1" class="data row8 col1" >Attrited Customer</td>
#       <td id="T_01157_row8_col2" class="data row8 col2" >612</td>
#       <td id="T_01157_row8_col3" class="data row8 col3" >17.186184</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_01157_row9_col0" class="data row9 col0" >Less than $40K</td>
#       <td id="T_01157_row9_col1" class="data row9 col1" >Existing Customer</td>
#       <td id="T_01157_row9_col2" class="data row9 col2" >2949</td>
#       <td id="T_01157_row9_col3" class="data row9 col3" >82.813816</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_01157_row10_col0" class="data row10 col0" >Unknown</td>
#       <td id="T_01157_row10_col1" class="data row10 col1" >Attrited Customer</td>
#       <td id="T_01157_row10_col2" class="data row10 col2" >187</td>
#       <td id="T_01157_row10_col3" class="data row10 col3" >16.816547</td>
#     </tr>
#     <tr>
#       <th id="T_01157_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_01157_row11_col0" class="data row11 col0" >Unknown</td>
#       <td id="T_01157_row11_col1" class="data row11 col1" >Existing Customer</td>
#       <td id="T_01157_row11_col2" class="data row11 col2" >925</td>
#       <td id="T_01157_row11_col3" class="data row11 col3" >83.183453</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Client Status by Card Category
df_card = df.groupby(by=['Card_Category','status']).agg(cnt_client=('CLIENTNUM','count')).sort_values(by=['Card_Category','status'],ascending=True).reset_index()
df_card['percentage'] = 100 * df_card['cnt_client'] / df_card.groupby('Card_Category')['cnt_client'].transform('sum')
df_card.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_dfd7a_row0_col2 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_dfd7a_row0_col3 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_dfd7a_row1_col2, #T_dfd7a_row7_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_dfd7a_row1_col3 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_dfd7a_row2_col2, #T_dfd7a_row4_col2, #T_dfd7a_row5_col2, #T_dfd7a_row6_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_dfd7a_row2_col3 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_dfd7a_row3_col2, #T_dfd7a_row6_col2 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_dfd7a_row3_col3 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_dfd7a_row4_col3 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_dfd7a_row5_col3 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_dfd7a_row7_col2 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# </style>
# <table id="T_dfd7a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Card_Category</th>
#       <th class="col_heading level0 col1" >status</th>
#       <th class="col_heading level0 col2" >cnt_client</th>
#       <th class="col_heading level0 col3" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfd7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfd7a_row0_col0" class="data row0 col0" >Blue</td>
#       <td id="T_dfd7a_row0_col1" class="data row0 col1" >Attrited Customer</td>
#       <td id="T_dfd7a_row0_col2" class="data row0 col2" >1519</td>
#       <td id="T_dfd7a_row0_col3" class="data row0 col3" >16.097923</td>
#     </tr>
#     <tr>
#       <th id="T_dfd7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfd7a_row1_col0" class="data row1 col0" >Blue</td>
#       <td id="T_dfd7a_row1_col1" class="data row1 col1" >Existing Customer</td>
#       <td id="T_dfd7a_row1_col2" class="data row1 col2" >7917</td>
#       <td id="T_dfd7a_row1_col3" class="data row1 col3" >83.902077</td>
#     </tr>
#     <tr>
#       <th id="T_dfd7a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfd7a_row2_col0" class="data row2 col0" >Gold</td>
#       <td id="T_dfd7a_row2_col1" class="data row2 col1" >Attrited Customer</td>
#       <td id="T_dfd7a_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_dfd7a_row2_col3" class="data row2 col3" >18.103448</td>
#     </tr>
#     <tr>
#       <th id="T_dfd7a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfd7a_row3_col0" class="data row3 col0" >Gold</td>
#       <td id="T_dfd7a_row3_col1" class="data row3 col1" >Existing Customer</td>
#       <td id="T_dfd7a_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_dfd7a_row3_col3" class="data row3 col3" >81.896552</td>
#     </tr>
#     <tr>
#       <th id="T_dfd7a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dfd7a_row4_col0" class="data row4 col0" >Platinum</td>
#       <td id="T_dfd7a_row4_col1" class="data row4 col1" >Attrited Customer</td>
#       <td id="T_dfd7a_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_dfd7a_row4_col3" class="data row4 col3" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dfd7a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dfd7a_row5_col0" class="data row5 col0" >Platinum</td>
#       <td id="T_dfd7a_row5_col1" class="data row5 col1" >Existing Customer</td>
#       <td id="T_dfd7a_row5_col2" class="data row5 col2" >15</td>
#       <td id="T_dfd7a_row5_col3" class="data row5 col3" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dfd7a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dfd7a_row6_col0" class="data row6 col0" >Silver</td>
#       <td id="T_dfd7a_row6_col1" class="data row6 col1" >Attrited Customer</td>
#       <td id="T_dfd7a_row6_col2" class="data row6 col2" >82</td>
#       <td id="T_dfd7a_row6_col3" class="data row6 col3" >14.774775</td>
#     </tr>
#     <tr>
#       <th id="T_dfd7a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dfd7a_row7_col0" class="data row7 col0" >Silver</td>
#       <td id="T_dfd7a_row7_col1" class="data row7 col1" >Existing Customer</td>
#       <td id="T_dfd7a_row7_col2" class="data row7 col2" >473</td>
#       <td id="T_dfd7a_row7_col3" class="data row7 col3" >85.225225</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Bivariate Analysis : Numerical Features vs Target**

# %% [markdown]
# Credit Limit vs Target

# %%
sns.boxplot(x='status', y='Credit_Limit', data=df, palette = 'mako')
plt.grid()
plt.show()

# %%
df_cclimit = df.groupby('status').agg(credit_limit_med=('Credit_Limit','median')).reset_index()
df_cclimit.style.background_gradient(cmap='mako')
# Out:
# <style type="text/css">
# #T_226d5_row0_col1 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_226d5_row1_col1 {
#   background-color: #def5e5;
#   color: #000000;
# }
# </style>
# <table id="T_226d5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >status</th>
#       <th class="col_heading level0 col1" >credit_limit_med</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_226d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_226d5_row0_col0" class="data row0 col0" >Attrited Customer</td>
#       <td id="T_226d5_row0_col1" class="data row0 col1" >4178.000000</td>
#     </tr>
#     <tr>
#       <th id="T_226d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_226d5_row1_col0" class="data row1 col0" >Existing Customer</td>
#       <td id="T_226d5_row1_col1" class="data row1 col1" >4643.500000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Inactive Months vs Target

# %%
sns.boxplot(x='status', y='Months_Inactive_12_mon', data=df, palette = 'mako')
plt.grid()
plt.show()

# %%
df_inactive= df.groupby('status').agg(inactive_med=('Months_Inactive_12_mon','median')).reset_index()
df_inactive.style.background_gradient(cmap='mako')
# Out:
# <style type="text/css">
# #T_d86e6_row0_col1 {
#   background-color: #def5e5;
#   color: #000000;
# }
# #T_d86e6_row1_col1 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d86e6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >status</th>
#       <th class="col_heading level0 col1" >inactive_med</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d86e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d86e6_row0_col0" class="data row0 col0" >Attrited Customer</td>
#       <td id="T_d86e6_row0_col1" class="data row0 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d86e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d86e6_row1_col0" class="data row1 col0" >Existing Customer</td>
#       <td id="T_d86e6_row1_col1" class="data row1 col1" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Client Age

# %%
attrited_age = df[df['status']=='Attrited Customer']['Customer_Age']
existing_age = df[df['status']=='Existing Customer']['Customer_Age']

# %%
plt.figure(figsize=(10,3))
plt.hist(df['Customer_Age'], bins=10, edgecolor='black', color='steelblue')
plt.title('Age of Client (in years) in Client Credit Card History\n')
plt.xlabel('Age Bucket')
plt.ylabel('Number of Clients')
plt.show()

plt.figure(figsize=(10,3))
plt.hist(attrited_age, bins=10, edgecolor='black', color='teal')
plt.title('Age of Client (in years) who have "Existing Customer" status\n')
plt.xlabel('Age')
plt.ylabel('Number of Clients')
plt.show()

plt.figure(figsize=(10,3))
plt.hist(existing_age, bins=10, edgecolor='black', color='maroon')
plt.title('Age of Client (in years) who have "Attrited Customer" Status\n')
plt.xlabel('Age')
plt.ylabel('Number of Clients')
plt.show()

# %% [markdown]
# **Multivariate Analysis**

# %% [markdown]
# **Grouped By Education Level**

# %% [markdown]
# 1. Education Level, Dependent Count, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Dependent_count', 
            hue = 'status', 
            col = 'Education_Level', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_edu1 = df.groupby(by=['Education_Level','Marital_Status','status']).agg(cnt_client=('Dependent_count','mean')).sort_values(by=['Education_Level','Marital_Status','status','cnt_client'],ascending=True).reset_index()
df_edu1.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_c805f_row0_col3 {
#   background-color: #ade0d4;
#   color: #000000;
# }
# #T_c805f_row1_col3, #T_c805f_row16_col3, #T_c805f_row35_col3 {
#   background-color: #44af79;
#   color: #f1f1f1;
# }
# #T_c805f_row2_col3 {
#   background-color: #2c9553;
#   color: #f1f1f1;
# }
# #T_c805f_row3_col3 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_c805f_row4_col3 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_c805f_row5_col3 {
#   background-color: #55b98f;
#   color: #f1f1f1;
# }
# #T_c805f_row6_col3 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_c805f_row7_col3 {
#   background-color: #39a569;
#   color: #f1f1f1;
# }
# #T_c805f_row8_col3, #T_c805f_row31_col3 {
#   background-color: #3aa66a;
#   color: #f1f1f1;
# }
# #T_c805f_row9_col3 {
#   background-color: #349f61;
#   color: #f1f1f1;
# }
# #T_c805f_row10_col3 {
#   background-color: #6dc5a9;
#   color: #000000;
# }
# #T_c805f_row11_col3, #T_c805f_row19_col3 {
#   background-color: #59bb93;
#   color: #f1f1f1;
# }
# #T_c805f_row12_col3 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_c805f_row13_col3 {
#   background-color: #77c9b0;
#   color: #000000;
# }
# #T_c805f_row14_col3 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_c805f_row15_col3 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_c805f_row17_col3 {
#   background-color: #4ab381;
#   color: #f1f1f1;
# }
# #T_c805f_row18_col3 {
#   background-color: #38a367;
#   color: #f1f1f1;
# }
# #T_c805f_row20_col3, #T_c805f_row37_col3 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# #T_c805f_row21_col3, #T_c805f_row27_col3 {
#   background-color: #5ebe9b;
#   color: #000000;
# }
# #T_c805f_row22_col3 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_c805f_row23_col3 {
#   background-color: #4bb382;
#   color: #f1f1f1;
# }
# #T_c805f_row24_col3 {
#   background-color: #41ae77;
#   color: #f1f1f1;
# }
# #T_c805f_row25_col3, #T_c805f_row40_col3, #T_c805f_row45_col3 {
#   background-color: #60bf9c;
#   color: #000000;
# }
# #T_c805f_row26_col3 {
#   background-color: #2d9655;
#   color: #f1f1f1;
# }
# #T_c805f_row28_col3 {
#   background-color: #afe1d5;
#   color: #000000;
# }
# #T_c805f_row29_col3, #T_c805f_row36_col3 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_c805f_row30_col3 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_c805f_row32_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_c805f_row33_col3, #T_c805f_row50_col3 {
#   background-color: #2a9350;
#   color: #f1f1f1;
# }
# #T_c805f_row34_col3 {
#   background-color: #5bbc96;
#   color: #f1f1f1;
# }
# #T_c805f_row38_col3 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_c805f_row39_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c805f_row41_col3 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_c805f_row42_col3 {
#   background-color: #319c5c;
#   color: #f1f1f1;
# }
# #T_c805f_row43_col3, #T_c805f_row46_col3 {
#   background-color: #53b88c;
#   color: #f1f1f1;
# }
# #T_c805f_row44_col3 {
#   background-color: #52b78b;
#   color: #f1f1f1;
# }
# #T_c805f_row47_col3 {
#   background-color: #40ad75;
#   color: #f1f1f1;
# }
# #T_c805f_row48_col3 {
#   background-color: #45b07b;
#   color: #f1f1f1;
# }
# #T_c805f_row49_col3 {
#   background-color: #47b17e;
#   color: #f1f1f1;
# }
# #T_c805f_row51_col3 {
#   background-color: #5cbd98;
#   color: #f1f1f1;
# }
# #T_c805f_row52_col3 {
#   background-color: #4eb586;
#   color: #f1f1f1;
# }
# #T_c805f_row53_col3 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_c805f_row54_col3 {
#   background-color: #3fac74;
#   color: #f1f1f1;
# }
# #T_c805f_row55_col3 {
#   background-color: #28914d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c805f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Education_Level</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >cnt_client</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c805f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c805f_row0_col0" class="data row0 col0" >College</td>
#       <td id="T_c805f_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_c805f_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_c805f_row0_col3" class="data row0 col3" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c805f_row1_col0" class="data row1 col0" >College</td>
#       <td id="T_c805f_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_c805f_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_c805f_row1_col3" class="data row1 col3" >2.440000</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c805f_row2_col0" class="data row2 col0" >College</td>
#       <td id="T_c805f_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_c805f_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_c805f_row2_col3" class="data row2 col3" >2.591549</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c805f_row3_col0" class="data row3 col0" >College</td>
#       <td id="T_c805f_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_c805f_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_c805f_row3_col3" class="data row3 col3" >2.345960</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c805f_row4_col0" class="data row4 col0" >College</td>
#       <td id="T_c805f_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_c805f_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_c805f_row4_col3" class="data row4 col3" >2.111111</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c805f_row5_col0" class="data row5 col0" >College</td>
#       <td id="T_c805f_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_c805f_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_c805f_row5_col3" class="data row5 col3" >2.352941</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c805f_row6_col0" class="data row6 col0" >College</td>
#       <td id="T_c805f_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_c805f_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_c805f_row6_col3" class="data row6 col3" >1.777778</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c805f_row7_col0" class="data row7 col0" >College</td>
#       <td id="T_c805f_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_c805f_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_c805f_row7_col3" class="data row7 col3" >2.507692</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c805f_row8_col0" class="data row8 col0" >Doctorate</td>
#       <td id="T_c805f_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_c805f_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_c805f_row8_col3" class="data row8 col3" >2.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c805f_row9_col0" class="data row9 col0" >Doctorate</td>
#       <td id="T_c805f_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_c805f_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_c805f_row9_col3" class="data row9 col3" >2.535714</td>
#     </tr>
#     <tr>
#       <th id="T_c805f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c805f_row10_col0" class="data row10 col0" >Doctorate</td>
#       <td id="T_c805f_row10_col1" class="data row10 col1" >Married</td>
#       <td id="T_c805f_row10_col2" class="data row10 col2" >Attrited Customer</td>

# %% [markdown]
# 2. Education Level, Average Utilization Ratio, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Avg_Utilization_Ratio', 
            hue = 'status', 
            col = 'Education_Level', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_edu2 = df.groupby(by=['Education_Level','Marital_Status','status']).agg(avg_utilization_ratio=('Avg_Utilization_Ratio','mean')).sort_values(by=['Education_Level','Marital_Status','status','avg_utilization_ratio'],ascending=True).reset_index()
df_edu2.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_2f06a_row0_col3 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_2f06a_row1_col3, #T_2f06a_row23_col3 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_2f06a_row2_col3 {
#   background-color: #53b88c;
#   color: #f1f1f1;
# }
# #T_2f06a_row3_col3, #T_2f06a_row43_col3 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_2f06a_row4_col3, #T_2f06a_row20_col3, #T_2f06a_row34_col3 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_2f06a_row5_col3 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_2f06a_row6_col3 {
#   background-color: #2d9655;
#   color: #f1f1f1;
# }
# #T_2f06a_row7_col3 {
#   background-color: #28914d;
#   color: #f1f1f1;
# }
# #T_2f06a_row8_col3, #T_2f06a_row12_col3 {
#   background-color: #59bb93;
#   color: #f1f1f1;
# }
# #T_2f06a_row9_col3 {
#   background-color: #27904c;
#   color: #f1f1f1;
# }
# #T_2f06a_row10_col3 {
#   background-color: #329d5e;
#   color: #f1f1f1;
# }
# #T_2f06a_row11_col3 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_2f06a_row13_col3 {
#   background-color: #258d48;
#   color: #f1f1f1;
# }
# #T_2f06a_row14_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_2f06a_row15_col3, #T_2f06a_row47_col3 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_2f06a_row16_col3 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_2f06a_row17_col3 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_2f06a_row18_col3 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_2f06a_row19_col3 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_2f06a_row21_col3 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_2f06a_row22_col3 {
#   background-color: #61bf9e;
#   color: #000000;
# }
# #T_2f06a_row24_col3 {
#   background-color: #5bbc96;
#   color: #f1f1f1;
# }
# #T_2f06a_row25_col3 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_2f06a_row26_col3 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_2f06a_row27_col3 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_2f06a_row28_col3 {
#   background-color: #88d1bd;
#   color: #000000;
# }
# #T_2f06a_row29_col3 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_2f06a_row30_col3 {
#   background-color: #7acbb3;
#   color: #000000;
# }
# #T_2f06a_row31_col3 {
#   background-color: #309b5b;
#   color: #f1f1f1;
# }
# #T_2f06a_row32_col3 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_2f06a_row33_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2f06a_row35_col3 {
#   background-color: #005221;
#   color: #f1f1f1;
# }
# #T_2f06a_row36_col3 {
#   background-color: #3da96f;
#   color: #f1f1f1;
# }
# #T_2f06a_row37_col3 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_2f06a_row38_col3 {
#   background-color: #9cd9ca;
#   color: #000000;
# }
# #T_2f06a_row39_col3 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_2f06a_row40_col3 {
#   background-color: #4bb382;
#   color: #f1f1f1;
# }
# #T_2f06a_row41_col3 {
#   background-color: #37a266;
#   color: #f1f1f1;
# }
# #T_2f06a_row42_col3, #T_2f06a_row48_col3 {
#   background-color: #74c8ae;
#   color: #000000;
# }
# #T_2f06a_row44_col3 {
#   background-color: #41ae77;
#   color: #f1f1f1;
# }
# #T_2f06a_row45_col3 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_2f06a_row46_col3 {
#   background-color: #75c9af;
#   color: #000000;
# }
# #T_2f06a_row49_col3 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_2f06a_row50_col3 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_2f06a_row51_col3 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_2f06a_row52_col3 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_2f06a_row53_col3 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_2f06a_row54_col3 {
#   background-color: #8cd2bf;
#   color: #000000;
# }
# #T_2f06a_row55_col3 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f06a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Education_Level</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_utilization_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f06a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f06a_row0_col0" class="data row0 col0" >College</td>
#       <td id="T_2f06a_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_2f06a_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_2f06a_row0_col3" class="data row0 col3" >0.076636</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f06a_row1_col0" class="data row1 col0" >College</td>
#       <td id="T_2f06a_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_2f06a_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_2f06a_row1_col3" class="data row1 col3" >0.303293</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f06a_row2_col0" class="data row2 col0" >College</td>
#       <td id="T_2f06a_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_2f06a_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_2f06a_row2_col3" class="data row2 col3" >0.194000</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f06a_row3_col0" class="data row3 col0" >College</td>
#       <td id="T_2f06a_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_2f06a_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_2f06a_row3_col3" class="data row3 col3" >0.297742</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f06a_row4_col0" class="data row4 col0" >College</td>
#       <td id="T_2f06a_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_2f06a_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_2f06a_row4_col3" class="data row4 col3" >0.144016</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f06a_row5_col0" class="data row5 col0" >College</td>
#       <td id="T_2f06a_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_2f06a_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_2f06a_row5_col3" class="data row5 col3" >0.266189</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2f06a_row6_col0" class="data row6 col0" >College</td>
#       <td id="T_2f06a_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_2f06a_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_2f06a_row6_col3" class="data row6 col3" >0.244111</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2f06a_row7_col0" class="data row7 col0" >College</td>
#       <td id="T_2f06a_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_2f06a_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_2f06a_row7_col3" class="data row7 col3" >0.251231</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2f06a_row8_col0" class="data row8 col0" >Doctorate</td>
#       <td id="T_2f06a_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_2f06a_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_2f06a_row8_col3" class="data row8 col3" >0.187375</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2f06a_row9_col0" class="data row9 col0" >Doctorate</td>
#       <td id="T_2f06a_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_2f06a_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_2f06a_row9_col3" class="data row9 col3" >0.252786</td>
#     </tr>
#     <tr>
#       <th id="T_2f06a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2f06a_

# %% [markdown]
# 3. Education Level, Credit Limit, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Credit_Limit', 
            hue = 'status', 
            col = 'Education_Level', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_edu3 = df.groupby(by=['Education_Level','Marital_Status','status']).agg(avg_credit_limit=('Credit_Limit','mean')).sort_values(by=['Education_Level','Marital_Status','status','avg_credit_limit'],ascending=True).reset_index()
df_edu3.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_9d23f_row0_col3 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_9d23f_row1_col3 {
#   background-color: #b4e2d8;
#   color: #000000;
# }
# #T_9d23f_row2_col3 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_9d23f_row3_col3, #T_9d23f_row53_col3 {
#   background-color: #90d4c3;
#   color: #000000;
# }
# #T_9d23f_row4_col3 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_9d23f_row5_col3, #T_9d23f_row23_col3 {
#   background-color: #7ccbb4;
#   color: #000000;
# }
# #T_9d23f_row6_col3 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_9d23f_row7_col3 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_9d23f_row8_col3 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_9d23f_row9_col3 {
#   background-color: #4bb382;
#   color: #f1f1f1;
# }
# #T_9d23f_row10_col3, #T_9d23f_row42_col3 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_9d23f_row11_col3 {
#   background-color: #92d5c4;
#   color: #000000;
# }
# #T_9d23f_row12_col3 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_9d23f_row13_col3, #T_9d23f_row26_col3 {
#   background-color: #8cd2bf;
#   color: #000000;
# }
# #T_9d23f_row14_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_9d23f_row15_col3 {
#   background-color: #40ad75;
#   color: #f1f1f1;
# }
# #T_9d23f_row16_col3, #T_9d23f_row51_col3 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_9d23f_row17_col3 {
#   background-color: #74c8ae;
#   color: #000000;
# }
# #T_9d23f_row18_col3, #T_9d23f_row36_col3 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_9d23f_row19_col3 {
#   background-color: #9cd9ca;
#   color: #000000;
# }
# #T_9d23f_row20_col3 {
#   background-color: #7fcdb6;
#   color: #000000;
# }
# #T_9d23f_row21_col3 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_9d23f_row22_col3 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_9d23f_row24_col3 {
#   background-color: #309b5b;
#   color: #f1f1f1;
# }
# #T_9d23f_row25_col3 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_9d23f_row27_col3 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_9d23f_row28_col3 {
#   background-color: #8ad2be;
#   color: #000000;
# }
# #T_9d23f_row29_col3 {
#   background-color: #7dccb5;
#   color: #000000;
# }
# #T_9d23f_row30_col3 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_9d23f_row31_col3 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_9d23f_row32_col3 {
#   background-color: #6dc5a9;
#   color: #000000;
# }
# #T_9d23f_row33_col3 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_9d23f_row34_col3 {
#   background-color: #bfe7de;
#   color: #000000;
# }
# #T_9d23f_row35_col3 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_9d23f_row37_col3, #T_9d23f_row39_col3 {
#   background-color: #4db585;
#   color: #f1f1f1;
# }
# #T_9d23f_row38_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9d23f_row40_col3 {
#   background-color: #aadfd3;
#   color: #000000;
# }
# #T_9d23f_row41_col3 {
#   background-color: #349f61;
#   color: #f1f1f1;
# }
# #T_9d23f_row43_col3, #T_9d23f_row52_col3 {
#   background-color: #a2dcce;
#   color: #000000;
# }
# #T_9d23f_row44_col3 {
#   background-color: #88d1bd;
#   color: #000000;
# }
# #T_9d23f_row45_col3 {
#   background-color: #75c9af;
#   color: #000000;
# }
# #T_9d23f_row46_col3 {
#   background-color: #39a569;
#   color: #f1f1f1;
# }
# #T_9d23f_row47_col3 {
#   background-color: #61bf9e;
#   color: #000000;
# }
# #T_9d23f_row48_col3 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_9d23f_row49_col3 {
#   background-color: #62c09f;
#   color: #000000;
# }
# #T_9d23f_row50_col3 {
#   background-color: #ade0d4;
#   color: #000000;
# }
# #T_9d23f_row54_col3 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_9d23f_row55_col3 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# </style>
# <table id="T_9d23f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Education_Level</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_credit_limit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d23f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d23f_row0_col0" class="data row0 col0" >College</td>
#       <td id="T_9d23f_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_9d23f_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_9d23f_row0_col3" class="data row0 col3" >13778.454545</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d23f_row1_col0" class="data row1 col0" >College</td>
#       <td id="T_9d23f_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_9d23f_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_9d23f_row1_col3" class="data row1 col3" >7645.653333</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d23f_row2_col0" class="data row2 col0" >College</td>
#       <td id="T_9d23f_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_9d23f_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_9d23f_row2_col3" class="data row2 col3" >6155.591549</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d23f_row3_col0" class="data row3 col0" >College</td>
#       <td id="T_9d23f_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_9d23f_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_9d23f_row3_col3" class="data row3 col3" >8576.156566</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d23f_row4_col0" class="data row4 col0" >College</td>
#       <td id="T_9d23f_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_9d23f_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_9d23f_row4_col3" class="data row4 col3" >10228.015873</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d23f_row5_col0" class="data row5 col0" >College</td>
#       <td id="T_9d23f_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_9d23f_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_9d23f_row5_col3" class="data row5 col3" >9138.452012</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d23f_row6_col0" class="data row6 col0" >College</td>
#       <td id="T_9d23f_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_9d23f_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_9d23f_row6_col3" class="data row6 col3" >6941.333333</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d23f_row7_col0" class="data row7 col0" >College</td>
#       <td id="T_9d23f_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_9d23f_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_9d23f_row7_col3" class="data row7 col3" >8933.323077</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d23f_row8_col0" class="data row8 col0" >Doctorate</td>
#       <td id="T_9d23f_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_9d23f_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_9d23f_row8_col3" class="data row8 col3" >4996.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d23f_row9_col0" class="data row9 col0" >Doctorate</td>
#       <td id="T_9d23f_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_9d23f_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_9d23f_row9_col3" class="data row9 col3" >10678.107143</td>
#     </tr>
#     <tr>
#       <th id="T_9d23f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9d23f_row10_col0" class="dat

# %% [markdown]
# 4. Education Level, Average Open To Buy, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Avg_Open_To_Buy', 
            hue = 'status', 
            col = 'Education_Level', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_edu5 = df.groupby(by=['Education_Level','Marital_Status','status']).agg(avg_opentobuy=('Avg_Open_To_Buy','mean')).sort_values(by=['Education_Level','Marital_Status','status','avg_opentobuy'],ascending=True).reset_index()
df_edu5.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_8fbd9_row0_col3 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_8fbd9_row1_col3 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_8fbd9_row2_col3 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_8fbd9_row3_col3, #T_8fbd9_row52_col3 {
#   background-color: #ade0d4;
#   color: #000000;
# }
# #T_8fbd9_row4_col3 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_8fbd9_row5_col3, #T_8fbd9_row44_col3 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_8fbd9_row6_col3 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_8fbd9_row7_col3, #T_8fbd9_row30_col3 {
#   background-color: #9fdacc;
#   color: #000000;
# }
# #T_8fbd9_row8_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_8fbd9_row9_col3 {
#   background-color: #5abb95;
#   color: #f1f1f1;
# }
# #T_8fbd9_row10_col3 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_8fbd9_row11_col3, #T_8fbd9_row50_col3 {
#   background-color: #b0e1d6;
#   color: #000000;
# }
# #T_8fbd9_row12_col3 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_8fbd9_row13_col3 {
#   background-color: #a2dcce;
#   color: #000000;
# }
# #T_8fbd9_row14_col3 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_8fbd9_row15_col3 {
#   background-color: #54b88e;
#   color: #f1f1f1;
# }
# #T_8fbd9_row16_col3 {
#   background-color: #97d7c7;
#   color: #000000;
# }
# #T_8fbd9_row17_col3, #T_8fbd9_row28_col3, #T_8fbd9_row45_col3 {
#   background-color: #90d4c3;
#   color: #000000;
# }
# #T_8fbd9_row18_col3, #T_8fbd9_row36_col3 {
#   background-color: #d1eeea;
#   color: #000000;
# }
# #T_8fbd9_row19_col3 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_8fbd9_row20_col3 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_8fbd9_row21_col3 {
#   background-color: #9cd9ca;
#   color: #000000;
# }
# #T_8fbd9_row22_col3 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_8fbd9_row23_col3 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_8fbd9_row24_col3 {
#   background-color: #3ca86d;
#   color: #f1f1f1;
# }
# #T_8fbd9_row25_col3 {
#   background-color: #b4e2d8;
#   color: #000000;
# }
# #T_8fbd9_row26_col3 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_8fbd9_row27_col3 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_8fbd9_row29_col3 {
#   background-color: #9ad8ca;
#   color: #000000;
# }
# #T_8fbd9_row31_col3 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_8fbd9_row32_col3 {
#   background-color: #72c7ad;
#   color: #000000;
# }
# #T_8fbd9_row33_col3 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_8fbd9_row34_col3 {
#   background-color: #caebe5;
#   color: #000000;
# }
# #T_8fbd9_row35_col3 {
#   background-color: #d0ede9;
#   color: #000000;
# }
# #T_8fbd9_row37_col3 {
#   background-color: #5dbd99;
#   color: #000000;
# }
# #T_8fbd9_row38_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8fbd9_row39_col3 {
#   background-color: #5ebe9b;
#   color: #000000;
# }
# #T_8fbd9_row40_col3 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_8fbd9_row41_col3 {
#   background-color: #3fac74;
#   color: #f1f1f1;
# }
# #T_8fbd9_row42_col3 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_8fbd9_row43_col3 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_8fbd9_row46_col3 {
#   background-color: #38a367;
#   color: #f1f1f1;
# }
# #T_8fbd9_row47_col3 {
#   background-color: #7dccb5;
#   color: #000000;
# }
# #T_8fbd9_row48_col3 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_8fbd9_row49_col3 {
#   background-color: #78cab1;
#   color: #000000;
# }
# #T_8fbd9_row51_col3 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_8fbd9_row53_col3 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_8fbd9_row54_col3 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_8fbd9_row55_col3 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# </style>
# <table id="T_8fbd9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Education_Level</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_opentobuy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fbd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fbd9_row0_col0" class="data row0 col0" >College</td>
#       <td id="T_8fbd9_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_8fbd9_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_8fbd9_row0_col3" class="data row0 col3" >13286.727273</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8fbd9_row1_col0" class="data row1 col0" >College</td>
#       <td id="T_8fbd9_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_8fbd9_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_8fbd9_row1_col3" class="data row1 col3" >6432.226667</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8fbd9_row2_col0" class="data row2 col0" >College</td>
#       <td id="T_8fbd9_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_8fbd9_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_8fbd9_row2_col3" class="data row2 col3" >5379.690141</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8fbd9_row3_col0" class="data row3 col0" >College</td>
#       <td id="T_8fbd9_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_8fbd9_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_8fbd9_row3_col3" class="data row3 col3" >7335.545455</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8fbd9_row4_col0" class="data row4 col0" >College</td>
#       <td id="T_8fbd9_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_8fbd9_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_8fbd9_row4_col3" class="data row4 col3" >9632.317460</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8fbd9_row5_col0" class="data row5 col0" >College</td>
#       <td id="T_8fbd9_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_8fbd9_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_8fbd9_row5_col3" class="data row5 col3" >7947.557276</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8fbd9_row6_col0" class="data row6 col0" >College</td>
#       <td id="T_8fbd9_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_8fbd9_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_8fbd9_row6_col3" class="data row6 col3" >6200.444444</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8fbd9_row7_col0" class="data row7 col0" >College</td>
#       <td id="T_8fbd9_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_8fbd9_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_8fbd9_row7_col3" class="data row7 col3" >7719.384615</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8fbd9_row8_col0" class="data row8 col0" >Doctorate</td>
#       <td id="T_8fbd9_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_8fbd9_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_8fbd9_row8_col3" class="data row8 col3" >4056.750000</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8fbd9_row9_col0" class="data row9 col0" >Doctorate</td>
#       <td id="T_8fbd9_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_8fbd9_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_8fbd9_row9_col3" class="data row9 col3" >9502.214286</td>
#     </tr>
#     <tr>
#       <th id="T_8fbd9_level0_row10" class="row_heading level0 row10" >10</th>

# %% [markdown]
# 5. Education Level, Total Transaction Amount, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Total_Trans_Amt', 
            hue = 'status', 
            col = 'Education_Level', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_edu6 = df.groupby(by=['Education_Level','Marital_Status','status']).agg(avg_trans_amt=('Total_Trans_Amt','mean')).sort_values(by=['Education_Level','Marital_Status','status','avg_trans_amt'],ascending=True).reset_index()
df_edu6.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_093e3_row0_col3 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_093e3_row1_col3 {
#   background-color: #4ab381;
#   color: #f1f1f1;
# }
# #T_093e3_row2_col3 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_093e3_row3_col3 {
#   background-color: #2e9756;
#   color: #f1f1f1;
# }
# #T_093e3_row4_col3, #T_093e3_row30_col3 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_093e3_row5_col3 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_093e3_row6_col3 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_093e3_row7_col3, #T_093e3_row21_col3, #T_093e3_row45_col3, #T_093e3_row53_col3 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_093e3_row8_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_093e3_row9_col3 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_093e3_row10_col3 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_093e3_row11_col3 {
#   background-color: #319c5c;
#   color: #f1f1f1;
# }
# #T_093e3_row12_col3 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_093e3_row13_col3 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_093e3_row14_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_093e3_row15_col3 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_093e3_row16_col3 {
#   background-color: #94d6c5;
#   color: #000000;
# }
# #T_093e3_row17_col3 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_093e3_row18_col3 {
#   background-color: #c7eae3;
#   color: #000000;
# }
# #T_093e3_row19_col3 {
#   background-color: #329d5e;
#   color: #f1f1f1;
# }
# #T_093e3_row20_col3, #T_093e3_row42_col3 {
#   background-color: #b4e2d8;
#   color: #000000;
# }
# #T_093e3_row22_col3, #T_093e3_row34_col3 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_093e3_row23_col3 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_093e3_row24_col3 {
#   background-color: #b0e1d6;
#   color: #000000;
# }
# #T_093e3_row25_col3 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_093e3_row26_col3 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_093e3_row27_col3 {
#   background-color: #3eaa70;
#   color: #f1f1f1;
# }
# #T_093e3_row28_col3 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_093e3_row29_col3 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_093e3_row31_col3 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_093e3_row32_col3 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_093e3_row33_col3 {
#   background-color: #005221;
#   color: #f1f1f1;
# }
# #T_093e3_row35_col3 {
#   background-color: #2f9a59;
#   color: #f1f1f1;
# }
# #T_093e3_row36_col3 {
#   background-color: #5ebe9b;
#   color: #000000;
# }
# #T_093e3_row37_col3 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_093e3_row38_col3 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_093e3_row39_col3 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_093e3_row40_col3 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_093e3_row41_col3 {
#   background-color: #258d48;
#   color: #f1f1f1;
# }
# #T_093e3_row43_col3 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_093e3_row44_col3 {
#   background-color: #bae5dc;
#   color: #000000;
# }
# #T_093e3_row46_col3 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_093e3_row47_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_093e3_row48_col3 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_093e3_row49_col3 {
#   background-color: #39a569;
#   color: #f1f1f1;
# }
# #T_093e3_row50_col3 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_093e3_row51_col3 {
#   background-color: #28914d;
#   color: #f1f1f1;
# }
# #T_093e3_row52_col3 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_093e3_row54_col3 {
#   background-color: #3fac74;
#   color: #f1f1f1;
# }
# #T_093e3_row55_col3 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_093e3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Education_Level</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_trans_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_093e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_093e3_row0_col0" class="data row0 col0" >College</td>
#       <td id="T_093e3_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_093e3_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_093e3_row0_col3" class="data row0 col3" >2274.454545</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_093e3_row1_col0" class="data row1 col0" >College</td>
#       <td id="T_093e3_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_093e3_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_093e3_row1_col3" class="data row1 col3" >4075.293333</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_093e3_row2_col0" class="data row2 col0" >College</td>
#       <td id="T_093e3_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_093e3_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_093e3_row2_col3" class="data row2 col3" >2582.042254</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_093e3_row3_col0" class="data row3 col0" >College</td>
#       <td id="T_093e3_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_093e3_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_093e3_row3_col3" class="data row3 col3" >4427.949495</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_093e3_row4_col0" class="data row4 col0" >College</td>
#       <td id="T_093e3_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_093e3_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_093e3_row4_col3" class="data row4 col3" >3300.365079</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_093e3_row5_col0" class="data row5 col0" >College</td>
#       <td id="T_093e3_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_093e3_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_093e3_row5_col3" class="data row5 col3" >4646.356037</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_093e3_row6_col0" class="data row6 col0" >College</td>
#       <td id="T_093e3_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_093e3_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_093e3_row6_col3" class="data row6 col3" >2306.222222</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_093e3_row7_col0" class="data row7 col0" >College</td>
#       <td id="T_093e3_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_093e3_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_093e3_row7_col3" class="data row7 col3" >4834.169231</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_093e3_row8_col0" class="data row8 col0" >Doctorate</td>
#       <td id="T_093e3_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_093e3_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_093e3_row8_col3" class="data row8 col3" >2276.375000</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_093e3_row9_col0" class="data row9 col0" >Doctorate</td>
#       <td id="T_093e3_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_093e3_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_093e3_row9_col3" class="data row9 col3" >5213.035714</td>
#     </tr>
#     <tr>
#       <th id="T_093e3_level0

# %% [markdown]
# **Grouped By Income Category**

# %% [markdown]
# 1. Income Category, Dependent Count, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Dependent_count', 
            hue = 'status', 
            col = 'Income_Category', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_income1 = df.groupby(by=['Income_Category','Marital_Status','status']).agg(avg_dependent_cnt=('Dependent_count','mean')).sort_values(by=['Income_Category','Marital_Status','status','avg_dependent_cnt'],ascending=True).reset_index()
df_income1.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_3f99a_row0_col3 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_3f99a_row1_col3 {
#   background-color: #74c8ae;
#   color: #000000;
# }
# #T_3f99a_row2_col3 {
#   background-color: #55b98f;
#   color: #f1f1f1;
# }
# #T_3f99a_row3_col3 {
#   background-color: #85cfbb;
#   color: #000000;
# }
# #T_3f99a_row4_col3 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_3f99a_row5_col3 {
#   background-color: #5cbd98;
#   color: #f1f1f1;
# }
# #T_3f99a_row6_col3, #T_3f99a_row27_col3 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_3f99a_row7_col3, #T_3f99a_row47_col3 {
#   background-color: #75c9af;
#   color: #000000;
# }
# #T_3f99a_row8_col3 {
#   background-color: #2f9858;
#   color: #f1f1f1;
# }
# #T_3f99a_row9_col3 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_3f99a_row10_col3 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_3f99a_row11_col3 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_3f99a_row12_col3 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_3f99a_row13_col3 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_3f99a_row14_col3 {
#   background-color: #3fac74;
#   color: #f1f1f1;
# }
# #T_3f99a_row15_col3 {
#   background-color: #5abb95;
#   color: #f1f1f1;
# }
# #T_3f99a_row16_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_3f99a_row17_col3 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_3f99a_row18_col3 {
#   background-color: #329d5e;
#   color: #f1f1f1;
# }
# #T_3f99a_row19_col3, #T_3f99a_row29_col3 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_3f99a_row20_col3 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_3f99a_row21_col3 {
#   background-color: #90d4c3;
#   color: #000000;
# }
# #T_3f99a_row22_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3f99a_row23_col3 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_3f99a_row24_col3, #T_3f99a_row36_col3 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_3f99a_row25_col3 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_3f99a_row26_col3 {
#   background-color: #2f9a59;
#   color: #f1f1f1;
# }
# #T_3f99a_row28_col3, #T_3f99a_row31_col3 {
#   background-color: #4fb688;
#   color: #f1f1f1;
# }
# #T_3f99a_row30_col3 {
#   background-color: #54b88e;
#   color: #f1f1f1;
# }
# #T_3f99a_row32_col3 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_3f99a_row33_col3 {
#   background-color: #c7eae3;
#   color: #000000;
# }
# #T_3f99a_row34_col3 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# #T_3f99a_row35_col3 {
#   background-color: #cdece7;
#   color: #000000;
# }
# #T_3f99a_row37_col3 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_3f99a_row38_col3 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_3f99a_row39_col3 {
#   background-color: #70c6ac;
#   color: #000000;
# }
# #T_3f99a_row40_col3 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_3f99a_row41_col3 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_3f99a_row42_col3, #T_3f99a_row43_col3 {
#   background-color: #afe1d5;
#   color: #000000;
# }
# #T_3f99a_row44_col3 {
#   background-color: #d3eeeb;
#   color: #000000;
# }
# #T_3f99a_row45_col3 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_3f99a_row46_col3 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f99a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Income_Category</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_dependent_cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f99a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f99a_row0_col0" class="data row0 col0" >$120K +</td>
#       <td id="T_3f99a_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_3f99a_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_3f99a_row0_col3" class="data row0 col3" >2.888889</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f99a_row1_col0" class="data row1 col0" >$120K +</td>
#       <td id="T_3f99a_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_3f99a_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_3f99a_row1_col3" class="data row1 col3" >2.465116</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3f99a_row2_col0" class="data row2 col0" >$120K +</td>
#       <td id="T_3f99a_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_3f99a_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_3f99a_row2_col3" class="data row2 col3" >2.557692</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3f99a_row3_col0" class="data row3 col0" >$120K +</td>
#       <td id="T_3f99a_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_3f99a_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_3f99a_row3_col3" class="data row3 col3" >2.423841</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3f99a_row4_col0" class="data row4 col0" >$120K +</td>
#       <td id="T_3f99a_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_3f99a_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_3f99a_row4_col3" class="data row4 col3" >2.237288</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3f99a_row5_col0" class="data row5 col0" >$120K +</td>
#       <td id="T_3f99a_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_3f99a_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_3f99a_row5_col3" class="data row5 col3" >2.534884</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3f99a_row6_col0" class="data row6 col0" >$120K +</td>
#       <td id="T_3f99a_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_3f99a_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_3f99a_row6_col3" class="data row6 col3" >2.500000</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3f99a_row7_col0" class="data row7 col0" >$120K +</td>
#       <td id="T_3f99a_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_3f99a_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_3f99a_row7_col3" class="data row7 col3" >2.463415</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3f99a_row8_col0" class="data row8 col0" >$40K - $60K</td>
#       <td id="T_3f99a_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_3f99a_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_3f99a_row8_col3" class="data row8 col3" >2.700000</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3f99a_row9_col0" class="data row9 col0" >$40K - $60K</td>
#       <td id="T_3f99a_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_3f99a_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_3f99a_row9_col3" class="data row9 col3" >2.491525</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3f99a_row10_col0" class="data row10 col0" >$40K - $60K</td>
#       <td id="T_3f99a_row10_col1" class="data row10 col1" >Married</td>
#       <td id="T_3f99a_row10_col2" class="data row10 col2" >Attrited Customer</td>
#       <td id="T_3f99a_row10_col3" class="data row10 col3" >2.480315</td>
#     </tr>
#     <tr>
#       <th id="T_3f99a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3f99a_row11_col0" class="data row11 col0" >$40K - $60K</td>
#       <td id="T_3f99a_row11_col1" class="data row11 col1" >Marri

# %% [markdown]
# 2. Income Category, Average Utilization Ratio, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Avg_Utilization_Ratio', 
            hue = 'status', 
            col = 'Income_Category', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_income2 = df.groupby(by=['Income_Category','Marital_Status','status']).agg(avg_util_ratio=('Avg_Utilization_Ratio','mean')).sort_values(by=['Income_Category','Marital_Status','status','avg_util_ratio'],ascending=True).reset_index()
df_income2.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_7524d_row0_col3, #T_7524d_row16_col3, #T_7524d_row24_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_7524d_row1_col3 {
#   background-color: #b0e1d6;
#   color: #000000;
# }
# #T_7524d_row2_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_7524d_row3_col3 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_7524d_row4_col3 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_7524d_row5_col3 {
#   background-color: #ceede8;
#   color: #000000;
# }
# #T_7524d_row6_col3, #T_7524d_row30_col3 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_7524d_row7_col3 {
#   background-color: #d1eeea;
#   color: #000000;
# }
# #T_7524d_row8_col3 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_7524d_row9_col3 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_7524d_row10_col3 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_7524d_row11_col3 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_7524d_row12_col3, #T_7524d_row21_col3 {
#   background-color: #92d5c4;
#   color: #000000;
# }
# #T_7524d_row13_col3 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_7524d_row14_col3 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_7524d_row15_col3 {
#   background-color: #319c5c;
#   color: #f1f1f1;
# }
# #T_7524d_row17_col3 {
#   background-color: #87d0bc;
#   color: #000000;
# }
# #T_7524d_row18_col3 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_7524d_row19_col3 {
#   background-color: #52b78b;
#   color: #f1f1f1;
# }
# #T_7524d_row20_col3 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_7524d_row22_col3 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_7524d_row23_col3 {
#   background-color: #88d1bd;
#   color: #000000;
# }
# #T_7524d_row25_col3 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_7524d_row26_col3 {
#   background-color: #c7eae3;
#   color: #000000;
# }
# #T_7524d_row27_col3 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_7524d_row28_col3 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_7524d_row29_col3, #T_7524d_row31_col3 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# #T_7524d_row32_col3 {
#   background-color: #4db585;
#   color: #f1f1f1;
# }
# #T_7524d_row33_col3 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_7524d_row34_col3 {
#   background-color: #77c9b0;
#   color: #000000;
# }
# #T_7524d_row35_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7524d_row36_col3 {
#   background-color: #70c6ac;
#   color: #000000;
# }
# #T_7524d_row37_col3 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_7524d_row38_col3 {
#   background-color: #59bb93;
#   color: #f1f1f1;
# }
# #T_7524d_row39_col3 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_7524d_row40_col3 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_7524d_row41_col3 {
#   background-color: #a2dcce;
#   color: #000000;
# }
# #T_7524d_row42_col3 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_7524d_row43_col3 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_7524d_row44_col3 {
#   background-color: #b4e2d8;
#   color: #000000;
# }
# #T_7524d_row45_col3 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_7524d_row46_col3 {
#   background-color: #d3eeeb;
#   color: #000000;
# }
# #T_7524d_row47_col3 {
#   background-color: #72c7ad;
#   color: #000000;
# }
# </style>
# <table id="T_7524d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Income_Category</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_util_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7524d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7524d_row0_col0" class="data row0 col0" >$120K +</td>
#       <td id="T_7524d_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_7524d_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_7524d_row0_col3" class="data row0 col3" >0.041000</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7524d_row1_col0" class="data row1 col0" >$120K +</td>
#       <td id="T_7524d_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_7524d_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_7524d_row1_col3" class="data row1 col3" >0.163209</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7524d_row2_col0" class="data row2 col0" >$120K +</td>
#       <td id="T_7524d_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_7524d_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_7524d_row2_col3" class="data row2 col3" >0.056615</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7524d_row3_col0" class="data row3 col0" >$120K +</td>
#       <td id="T_7524d_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_7524d_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_7524d_row3_col3" class="data row3 col3" >0.140017</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7524d_row4_col0" class="data row4 col0" >$120K +</td>
#       <td id="T_7524d_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_7524d_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_7524d_row4_col3" class="data row4 col3" >0.074746</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7524d_row5_col0" class="data row5 col0" >$120K +</td>
#       <td id="T_7524d_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_7524d_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_7524d_row5_col3" class="data row5 col3" >0.132414</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7524d_row6_col0" class="data row6 col0" >$120K +</td>
#       <td id="T_7524d_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_7524d_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_7524d_row6_col3" class="data row6 col3" >0.068000</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7524d_row7_col0" class="data row7 col0" >$120K +</td>
#       <td id="T_7524d_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_7524d_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_7524d_row7_col3" class="data row7 col3" >0.126707</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7524d_row8_col0" class="data row8 col0" >$40K - $60K</td>
#       <td id="T_7524d_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_7524d_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_7524d_row8_col3" class="data row8 col3" >0.109200</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7524d_row9_col0" class="data row9 col0" >$40K - $60K</td>
#       <td id="T_7524d_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_7524d_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_7524d_row9_col3" class="data row9 col3" >0.330297</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7524d_row10_col0" class="data row10 col0" >$40K - $60K</td>
#       <td id="T_7524d_row10_col1" class="data row10 col1" >Married</td>
#       <td id="T_7524d_row10_col2" class="data row10 col2" >Attrited Customer</td>
#       <td id="T_7524d_row10_col3" class="data row10 col3" >0.170142</td>
#     </tr>
#     <tr>
#       <th id="T_7524d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7524d_row11_col0" class="data row11 col0" >$40K - $60K</td>
#       <td id="T_7

# %% [markdown]
# 3. Income Category, Credit Limit, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Credit_Limit', 
            hue = 'status', 
            col = 'Income_Category', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_income3 = df.groupby(by=['Income_Category','Marital_Status','status']).agg(avg_credit_limit=('Credit_Limit','mean')).sort_values(by=['Income_Category','Marital_Status','status','avg_credit_limit'],ascending=True).reset_index()
df_income3.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_afbfa_row0_col3 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_afbfa_row1_col3 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_afbfa_row2_col3 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_afbfa_row3_col3, #T_afbfa_row25_col3 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_afbfa_row4_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_afbfa_row5_col3 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_afbfa_row6_col3 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_afbfa_row7_col3 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_afbfa_row8_col3 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_afbfa_row9_col3 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_afbfa_row10_col3 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_afbfa_row11_col3, #T_afbfa_row14_col3 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_afbfa_row12_col3 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_afbfa_row13_col3 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_afbfa_row15_col3 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_afbfa_row16_col3 {
#   background-color: #5ebe9b;
#   color: #000000;
# }
# #T_afbfa_row17_col3 {
#   background-color: #88d1bd;
#   color: #000000;
# }
# #T_afbfa_row18_col3, #T_afbfa_row19_col3 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_afbfa_row20_col3 {
#   background-color: #7dccb5;
#   color: #000000;
# }
# #T_afbfa_row21_col3 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_afbfa_row22_col3 {
#   background-color: #afe1d5;
#   color: #000000;
# }
# #T_afbfa_row23_col3 {
#   background-color: #6dc5a9;
#   color: #000000;
# }
# #T_afbfa_row24_col3 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_afbfa_row26_col3 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_afbfa_row27_col3 {
#   background-color: #3fab72;
#   color: #f1f1f1;
# }
# #T_afbfa_row28_col3 {
#   background-color: #2f9a59;
#   color: #f1f1f1;
# }
# #T_afbfa_row29_col3 {
#   background-color: #258d48;
#   color: #f1f1f1;
# }
# #T_afbfa_row30_col3 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_afbfa_row31_col3 {
#   background-color: #268f4a;
#   color: #f1f1f1;
# }
# #T_afbfa_row32_col3, #T_afbfa_row35_col3 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_afbfa_row33_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_afbfa_row34_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_afbfa_row36_col3 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_afbfa_row37_col3 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_afbfa_row38_col3 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_afbfa_row39_col3 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_afbfa_row40_col3 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_afbfa_row41_col3 {
#   background-color: #62c09f;
#   color: #000000;
# }
# #T_afbfa_row42_col3 {
#   background-color: #caebe5;
#   color: #000000;
# }
# #T_afbfa_row43_col3 {
#   background-color: #bce6dd;
#   color: #000000;
# }
# #T_afbfa_row44_col3 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_afbfa_row45_col3 {
#   background-color: #97d7c7;
#   color: #000000;
# }
# #T_afbfa_row46_col3 {
#   background-color: #ceede8;
#   color: #000000;
# }
# #T_afbfa_row47_col3 {
#   background-color: #8cd2bf;
#   color: #000000;
# }
# </style>
# <table id="T_afbfa_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Income_Category</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_credit_limit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afbfa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afbfa_row0_col0" class="data row0 col0" >$120K +</td>
#       <td id="T_afbfa_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_afbfa_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_afbfa_row0_col3" class="data row0 col3" >21071.333333</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_afbfa_row1_col0" class="data row1 col0" >$120K +</td>
#       <td id="T_afbfa_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_afbfa_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_afbfa_row1_col3" class="data row1 col3" >17751.162791</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_afbfa_row2_col0" class="data row2 col0" >$120K +</td>
#       <td id="T_afbfa_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_afbfa_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_afbfa_row2_col3" class="data row2 col3" >17625.384615</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_afbfa_row3_col0" class="data row3 col0" >$120K +</td>
#       <td id="T_afbfa_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_afbfa_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_afbfa_row3_col3" class="data row3 col3" >18869.986755</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_afbfa_row4_col0" class="data row4 col0" >$120K +</td>
#       <td id="T_afbfa_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_afbfa_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_afbfa_row4_col3" class="data row4 col3" >21394.593220</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_afbfa_row5_col0" class="data row5 col0" >$120K +</td>
#       <td id="T_afbfa_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_afbfa_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_afbfa_row5_col3" class="data row5 col3" >21163.023256</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_afbfa_row6_col0" class="data row6 col0" >$120K +</td>
#       <td id="T_afbfa_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_afbfa_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_afbfa_row6_col3" class="data row6 col3" >19681.500000</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_afbfa_row7_col0" class="data row7 col0" >$120K +</td>
#       <td id="T_afbfa_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_afbfa_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_afbfa_row7_col3" class="data row7 col3" >20387.170732</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_afbfa_row8_col0" class="data row8 col0" >$40K - $60K</td>
#       <td id="T_afbfa_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_afbfa_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_afbfa_row8_col3" class="data row8 col3" >5603.500000</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_afbfa_row9_col0" class="data row9 col0" >$40K - $60K</td>
#       <td id="T_afbfa_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_afbfa_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_afbfa_row9_col3" class="data row9 col3" >5777.050847</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_afbfa_row10_col0" class="data row10 col0" >$40K - $60K</td>
#       <td id="T_afbfa_row10_col1" class="data row10 col1" >Married</td>
#       <td id="T_afbfa_row10_col2" class="data row10 col2" >Attrited Customer</td>
#       <td id="T_afbfa_row10_col3" class="data row10 col3" >4675.669291</td>
#     </tr>
#     <tr>
#       <th id="T_afbfa_level0_row11" class="row_heading level0 row11" >11</th>

# %% [markdown]
# 4. Income Category, Average Open To Buy, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Avg_Open_To_Buy', 
            hue = 'status', 
            col = 'Income_Category', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %%
df_income4 = df.groupby(by=['Income_Category','Marital_Status','status']).agg(avg_opentobuy=('Avg_Open_To_Buy','mean')).sort_values(by=['Income_Category','Marital_Status','status','avg_opentobuy'],ascending=True).reset_index()
df_income4.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_24ab9_row0_col3 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_24ab9_row1_col3 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_24ab9_row2_col3 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_24ab9_row3_col3 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_24ab9_row4_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_24ab9_row5_col3 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_24ab9_row6_col3 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_24ab9_row7_col3 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_24ab9_row8_col3 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_24ab9_row9_col3 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_24ab9_row10_col3 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_24ab9_row11_col3 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_24ab9_row12_col3 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_24ab9_row13_col3 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_24ab9_row14_col3 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_24ab9_row15_col3 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_24ab9_row16_col3 {
#   background-color: #59bb93;
#   color: #f1f1f1;
# }
# #T_24ab9_row17_col3 {
#   background-color: #8dd3c0;
#   color: #000000;
# }
# #T_24ab9_row18_col3 {
#   background-color: #9cd9ca;
#   color: #000000;
# }
# #T_24ab9_row19_col3 {
#   background-color: #ade0d4;
#   color: #000000;
# }
# #T_24ab9_row20_col3 {
#   background-color: #77c9b0;
#   color: #000000;
# }
# #T_24ab9_row21_col3 {
#   background-color: #75c9af;
#   color: #000000;
# }
# #T_24ab9_row22_col3 {
#   background-color: #a2dcce;
#   color: #000000;
# }
# #T_24ab9_row23_col3 {
#   background-color: #72c7ad;
#   color: #000000;
# }
# #T_24ab9_row24_col3, #T_24ab9_row30_col3 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_24ab9_row25_col3 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_24ab9_row26_col3 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_24ab9_row27_col3 {
#   background-color: #46b17c;
#   color: #f1f1f1;
# }
# #T_24ab9_row28_col3 {
#   background-color: #2d9655;
#   color: #f1f1f1;
# }
# #T_24ab9_row29_col3 {
#   background-color: #2a9350;
#   color: #f1f1f1;
# }
# #T_24ab9_row31_col3 {
#   background-color: #2c9553;
#   color: #f1f1f1;
# }
# #T_24ab9_row32_col3, #T_24ab9_row36_col3 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_24ab9_row33_col3, #T_24ab9_row38_col3 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_24ab9_row34_col3, #T_24ab9_row37_col3 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_24ab9_row35_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_24ab9_row39_col3 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_24ab9_row40_col3 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_24ab9_row41_col3 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_24ab9_row42_col3 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_24ab9_row43_col3 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_24ab9_row44_col3 {
#   background-color: #afe1d5;
#   color: #000000;
# }
# #T_24ab9_row45_col3 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_24ab9_row46_col3 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_24ab9_row47_col3 {
#   background-color: #94d6c5;
#   color: #000000;
# }
# </style>
# <table id="T_24ab9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Income_Category</th>
#       <th class="col_heading level0 col1" >Marital_Status</th>
#       <th class="col_heading level0 col2" >status</th>
#       <th class="col_heading level0 col3" >avg_opentobuy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24ab9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24ab9_row0_col0" class="data row0 col0" >$120K +</td>
#       <td id="T_24ab9_row0_col1" class="data row0 col1" >Divorced</td>
#       <td id="T_24ab9_row0_col2" class="data row0 col2" >Attrited Customer</td>
#       <td id="T_24ab9_row0_col3" class="data row0 col3" >20390.222222</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24ab9_row1_col0" class="data row1 col0" >$120K +</td>
#       <td id="T_24ab9_row1_col1" class="data row1 col1" >Divorced</td>
#       <td id="T_24ab9_row1_col2" class="data row1 col2" >Existing Customer</td>
#       <td id="T_24ab9_row1_col3" class="data row1 col3" >16619.162791</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_24ab9_row2_col0" class="data row2 col0" >$120K +</td>
#       <td id="T_24ab9_row2_col1" class="data row2 col1" >Married</td>
#       <td id="T_24ab9_row2_col2" class="data row2 col2" >Attrited Customer</td>
#       <td id="T_24ab9_row2_col3" class="data row2 col3" >17093.500000</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_24ab9_row3_col0" class="data row3 col0" >$120K +</td>
#       <td id="T_24ab9_row3_col1" class="data row3 col1" >Married</td>
#       <td id="T_24ab9_row3_col2" class="data row3 col2" >Existing Customer</td>
#       <td id="T_24ab9_row3_col3" class="data row3 col3" >17483.500000</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_24ab9_row4_col0" class="data row4 col0" >$120K +</td>
#       <td id="T_24ab9_row4_col1" class="data row4 col1" >Single</td>
#       <td id="T_24ab9_row4_col2" class="data row4 col2" >Attrited Customer</td>
#       <td id="T_24ab9_row4_col3" class="data row4 col3" >20607.559322</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_24ab9_row5_col0" class="data row5 col0" >$120K +</td>
#       <td id="T_24ab9_row5_col1" class="data row5 col1" >Single</td>
#       <td id="T_24ab9_row5_col2" class="data row5 col2" >Existing Customer</td>
#       <td id="T_24ab9_row5_col3" class="data row5 col3" >19866.920930</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_24ab9_row6_col0" class="data row6 col0" >$120K +</td>
#       <td id="T_24ab9_row6_col1" class="data row6 col1" >Unknown</td>
#       <td id="T_24ab9_row6_col2" class="data row6 col2" >Attrited Customer</td>
#       <td id="T_24ab9_row6_col3" class="data row6 col3" >18817.500000</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_24ab9_row7_col0" class="data row7 col0" >$120K +</td>
#       <td id="T_24ab9_row7_col1" class="data row7 col1" >Unknown</td>
#       <td id="T_24ab9_row7_col2" class="data row7 col2" >Existing Customer</td>
#       <td id="T_24ab9_row7_col3" class="data row7 col3" >18995.146341</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_24ab9_row8_col0" class="data row8 col0" >$40K - $60K</td>
#       <td id="T_24ab9_row8_col1" class="data row8 col1" >Divorced</td>
#       <td id="T_24ab9_row8_col2" class="data row8 col2" >Attrited Customer</td>
#       <td id="T_24ab9_row8_col3" class="data row8 col3" >5038.950000</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_24ab9_row9_col0" class="data row9 col0" >$40K - $60K</td>
#       <td id="T_24ab9_row9_col1" class="data row9 col1" >Divorced</td>
#       <td id="T_24ab9_row9_col2" class="data row9 col2" >Existing Customer</td>
#       <td id="T_24ab9_row9_col3" class="data row9 col3" >4381.101695</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_24ab9_row10_col0" class="data row10 col0" >$40K - $60K</td>
#       <td id="T_24ab9_row10_col1" class="data row10 col1" >Married</td>
#       <td id="T_24ab9_row10_col2" class="data row10 col2" >Attrited Customer</td>
#       <td id="T_24ab9_row10_col3" class="data row10 col3" >4117.472441</td>
#     </tr>
#     <tr>
#       <th id="T_24ab9_level0_row11" class="row_heading level0 row11" >11</th>

# %% [markdown]
# 5. Income Category, Total Transaction Amount, Marital Status, Customer Status

# %%
fig = sns.catplot(x = 'Marital_Status',
            y = 'Total_Trans_Amt', 
            hue = 'status', 
            col = 'Income_Category', 
            kind = 'bar', palette = 'mako',
            data = df)

fig.set_xticklabels(rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# **Detecting Duplicate Data**

# %%
df_train = df.copy()

# %%
print('The number of duplicate data is:',df_train.duplicated().sum())
# there is no duplication
# Out:
# The number of duplicate data is: 0

# %%
# check for empty elements
print('Missing values status:', df_train.isnull().values.any())
df_null = pd.DataFrame(df_train.isnull().sum(), columns=['Total Null Values'])
df_null['Percentage'] = (df_null['Total Null Values']/df.shape[0])*100
df_null = df_null.sort_values(by=['Percentage'], ascending=False).reset_index()
df_null
# Out:
# Missing values status: False
#                        index  Total Null Values  Percentage
# 0                  CLIENTNUM                  0         0.0
# 1              Card_Category                  0         0.0
# 2             Total_Trans_Ct                  0         0.0
# 3            Total_Trans_Amt                  0         0.0
# 4            Avg_Open_To_Buy                  0         0.0
# 5        Total_Revolving_Bal                  0         0.0
# 6               Credit_Limit                  0         0.0
# 7      Contacts_Count_12_mon                  0         0.0
# 8     Months_Inactive_12_mon                  0         0.0
# 9   Total_Relationship_Count                  0         0.0
# 10            Months_on_book                  0         0.0
# 11           card_categoryid                  0         0.0
# 12                  idstatus                  0         0.0
# 13           Income_Category                  0         0.0
# 14            Marital_Status                  0         0.0
# 15                 Maritalid                  0         0.0
# 16           Education_Level                  0         0.0
# 17               Educationid                  0         0.0
# 18           Dependent_count                  0         0.0
# 19                    Gender                  0         0.0
# 20              Customer_Age                  0         0.0
# 21                    status                  0         0.0
# 22     Avg_Utilization_Ratio                  0         0.0

# %%
df_train.info(max_cols=200, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   idstatus                  10127 non-null  int64
#  2   status                    10127 non-null  object
#  3   Customer_Age              10127 non-null  int64
#  4   Gender                    10127 non-null  object
#  5   Dependent_count           10127 non-null  int64
#  6   Educationid               10127 non-null  int64
#  7   Education_Level           10127 non-null  object
#  8   Maritalid                 10127 non-null  int64
#  9   Marital_Status            10127 non-null  object
#  10  Income_Category           10127 non-null  object
#  11  card_categoryid           10127 non-null  int64
#  12  Card_Category             10127 non-null  object
#  13  Months_on_book            10127 non-null  int64
#  14  Total_Relationship_Count  10127 non-null  int64
#  15  Months_Inactive_12_mon    10127 non-null  int64
#  16  Contacts_Count_12_mon     10127 non-null  int64
#  17  Credit_Limit              10127 non-null  int64
#  18  Total_Revolving_Bal       10127 non-null  int64
#  19  Avg_Open_To_Buy           10127 non-null  int64
#  20  Total_Trans_Amt           10127 non-null  int64
#  21  Total_Trans_Ct            10127 non-null  int64
#  22  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(1), int64(16), object(6)
# memory usage: 1.8+ MB

# %%
#drop unecessary column
df_train = df_train.drop(columns=['idstatus','Educationid','Maritalid','card_categoryid'])
df.head()
# Out:
#    CLIENTNUM  idstatus             status  Customer_Age  Gender  \
# 0  768805383         1  Existing Customer            45    Male
# 1  818770008         1  Existing Customer            49  Female
# 2  713982108         1  Existing Customer            51    Male
# 3  769911858         1  Existing Customer            40  Female
# 4  709106358         1  Existing Customer            40    Male
#
#    Dependent_count  Educationid Education_Level  Maritalid Marital_Status  \
# 0                3            1     High School          1        Married
# 1                5            2        Graduate          2         Single
# 2                3            2        Graduate          1        Married
# 3                4            1     High School          3        Unknown
# 4                3            3      Uneducated          1        Married
#
#   Income_Category  card_categoryid Card_Category  Months_on_book  \
# 0     $60K - $80K                1          Blue              39
# 1  Less than $40K                1          Blue              44
# 2    $80K - $120K                1          Blue              36
# 3  Less than $40K                1          Blue              34
# 4     $60K - $80K                1          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Trans_Amt  \
# 0         12691                  777            11914             1144
# 1          8256                  864             7392             1291
# 2          3418                    0             3418             1887
# 3          3313                 2517              796             1171
# 4          4716                    0             4716              816
#
#    Total_Trans_Ct  Avg_Utilization_Ratio
# 0              42                  0.061
# 1              33                  0.105
# 2              20                  0.000
# 3              20                  0.760
# 4              28                  0.000

# %%
#dataset info after dropping unecassary column
df_train.info(max_cols=200, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   status                    10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  int64
#  14  Total_Revolving_Bal       10127 non-null  int64
#  15  Avg_Open_To_Buy           10127 non-null  int64
#  16  Total_Trans_Amt           10127 non-null  int64
#  17  Total_Trans_Ct            10127 non-null  int64
#  18  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(1), int64(12), object(6)
# memory usage: 1.5+ MB

# %%
# dataset that only consist numerical features [1]
int_features = df_train[['Customer_Age','Dependent_count', 'Months_on_book', 'Total_Relationship_Count']]

# %%
fig, axs = plt.subplots(ncols=4, nrows=1, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in int_features.items():
    sns.boxplot(y = k, data = int_features, ax=axs[index])
    index += 1
    if index == 5:
      break;
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# dataset that only consist numerical features [2]
int_features = df_train[['Contacts_Count_12_mon','Credit_Limit', 'Total_Revolving_Bal', 'Months_Inactive_12_mon']]

# %%
fig, axs = plt.subplots(ncols=4, nrows=1, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in int_features.items():
    sns.boxplot(y = k, data = int_features, ax=axs[index])
    index += 1
    if index == 5:
      break;
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# dataset that only consist numerical features [3]
int_features = df_train[['Avg_Open_To_Buy','Total_Trans_Amt', 'Total_Trans_Ct', 'Avg_Utilization_Ratio']]

# %%
fig, axs = plt.subplots(ncols=4, nrows=1, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in int_features.items():
    sns.boxplot(y = k, data = int_features, ax=axs[index])
    index += 1
    if index == 5:
      break;
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# **Data Preprocessing**

# %% [markdown]
# Encode Features

# %%
cleaned_df_train = df_train.drop(['CLIENTNUM'], axis=1)

from sklearn.preprocessing import LabelEncoder
#Convert all the non-numeric columns to numerical data types
for column in cleaned_df_train.columns:
    if cleaned_df_train[column].dtype == np.number: continue
    # Perform encoding for each non-numeric column
    cleaned_df_train[column] = LabelEncoder().fit_transform(cleaned_df_train[column])
print(cleaned_df_train.describe())
# Out:
#              status  Customer_Age        Gender  Dependent_count  \
# count  10127.000000  10127.000000  10127.000000     10127.000000
# mean       0.839340     20.325565      0.470919         2.346203
# std        0.367235      8.015598      0.499178         1.298908
# min        0.000000      0.000000      0.000000         0.000000
# 25%        1.000000     15.000000      0.000000         1.000000
# 50%        1.000000     20.000000      0.000000         2.000000
# 75%        1.000000     26.000000      1.000000         3.000000
# max        1.000000     44.000000      1.000000         5.000000
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# count     10127.000000    10127.000000     10127.000000   10127.000000
# mean          3.096574        1.463415         2.863928       0.179816
# std           1.834812        0.737808         1.504700       0.693039
# min           0.000000        0.000000         0.000000       0.000000
# 25%           2.000000        1.000000         2.000000       0.000000
# 50%           3.000000        1.000000         3.000000       0.000000
# 75%           5.000000        2.000000         4.000000       0.000000
# max           6.000000        3.000000         5.000000       3.000000
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# count    10127.000000              10127.000000            10127.000000
# mean        22.928409                  2.812580                2.341167
# std          7.986416                  1.554408                1.010622
# min          0.000000                  0.000000                0.000000
# 25%         18.000000                  2.000000                2.000000
# 50%         23.000000                  3.000000                2.000000
# 75%         27.000000                  4.000000                3.000000
# max         43.000000                  5.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   2650.715809           808.590797
# std                 1.106225   1968.490601           646.358114
# min                 0.000000      0.000000             0.000000
# 25%                 2.000000    932.000000            51.500000
# 50%                 2.000000   2276.000000           814.000000
# 75%                 3.000000   4308.500000          1319.000000
# max                 6.000000   6204.000000          1973.000000
#
#        Avg_Open_To_Buy  Total_Trans_Amt  Total_Trans_Ct  Avg_Utilization_Ratio
# count     10127.000000     10127.000000    10127.000000           10127.000000
# mean       2765.866199      2293.676903       54.857806               0.274894
# std        1984.939480      1303.049259       23.469870               0.275691
# min           0.000000         0.000000        0.000000               0.000000
# 25%        1017.500000      1132.500000       35.000000               0.023000
# 50%        2371.000000      2418.000000       57.000000               0.176000
# 75%        4417.500000      3215.000000       71.000000               0.503000
# max        6669.000000      5032.000000      125.000000               0.999000

# %%
cleaned_df_train.head()
# Out:
#    status  Customer_Age  Gender  Dependent_count  Education_Level  \
# 0       1            19       1                3                3
# 1       1            23       0                5                2
# 2       1            25       1                3                2
# 3       1            14       0                4                3
# 4       1            14       1                3                5
#
#    Marital_Status  Income_Category  Card_Category  Months_on_book  \
# 0               1                2              0              26
# 1               2                4              0              31
# 2               1                3              0              23
# 3               3                4              0              21
# 4               1                2              0               8
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         4                       1                      3
# 1                         5                       1                      2
# 2                         3                       1                      0
# 3                         2                       4                      1
# 4                         4                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Trans_Amt  \
# 0          4623                  324             4792              217
# 1          3623                  408             3806              338
# 2          1623                    0             2342              893
# 3          1552                 1973              575              236
# 4          2363                    0             2946               65
#
#    Total_Trans_Ct  Avg_Utilization_Ratio
# 0              32                  0.061
# 1              23                  0.105
# 2              10                  0.000
# 3              10                  0.760
# 4              18                  0.000

# %% [markdown]
# **Feature Selection**

# %%
x = cleaned_df_train.drop(['status'], axis=1)
y = cleaned_df_train['status']

# %%
# feature selection
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
featureScores = pd.concat([dfcolumns, dfscores], axis = 1)
featureScores.columns = ['Features', 'Score']
print('The features that correlate well with target feature:\n')
featureScores.sort_values(by=['Score'], ascending=False)
# Out:
# The features that correlate well with target feature:
#                     Features          Score
# 14           Total_Trans_Amt  402859.825865
# 12       Total_Revolving_Bal  279458.385229
# 11              Credit_Limit   27492.215069
# 15            Total_Trans_Ct   14027.238006
# 13           Avg_Open_To_Buy    2208.104454
# 10     Contacts_Count_12_mon     211.039445
# 8   Total_Relationship_Count     195.738278
# 9     Months_Inactive_12_mon     102.667123
# 16     Avg_Utilization_Ratio      89.116891
# 0               Customer_Age      10.634558
# 1                     Gender       7.443223
# 7             Months_on_book       5.276853
# 2            Dependent_count       2.626071
# 5            Income_Category       2.475170
# 4             Marital_Status       1.302755
# 6              Card_Category       0.986120
# 3            Education_Level       0.339231

# %% [markdown]
# It can be seen which features correlate well with payment difficulties.
# 1.   **Best features**: CLIENTNUM, Total_Trans_Amt, Total_Revolving_Bal, Credit_Limit,Total_Trans_Ct
# 2.   **Worst features**: Education_Level, Card_Category, Marital_Status, Income_Category and Dependent_count
#
# But, I use all features to continue the next analysis because this dataset has few features

# %%
# # create two different dataframe of majority and minority class 
# df_major = cleaned_df_train[cleaned_df_train['status']==1] 
# df_minor = cleaned_df_train[cleaned_df_train['status']==0]

# # upsample minority class
# df_minor_upsampled = resample(df_minor, 
#                               replace=True,    # sample with replacement
#                               n_samples= 8500, # to match majority class
#                               random_state=42)  # reproducible results

# # combine majority class with upsampled minority class
# df_upsampled = pd.concat([df_minor_upsampled, df_major])

# %%
# fig = plt.figure(figsize = (12,7))
# df_upsampled['status'].value_counts(normalize=True).plot(kind='bar', color= ['midnightblue','lightgrey'], alpha = 0.9, rot=0)
# plt.title('The Distribution of Clients Repayment Abilities\n', fontsize=14)
# plt.ylabel('Percentage of the Customers\n', fontsize=12)
# plt.xlabel('\nPayment Difficulty Status', fontsize=12)
# plt.show()

# %% [markdown]
# **Data Splitting**

# %%
# # define x and y features
# x_balanced = df_upsampled.drop(['status'], axis=1)
# y_balanced = df_upsampled['status']

# # splitting tha data
# X_train, X_test, y_train, y_test = train_test_split(x_balanced, y_balanced, test_size=0.2, random_state=42)
# print(X_train.shape, X_test.shape)

# %%
# splitting tha data
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape)
# Out:
# (8101, 17) (2026, 17)

# %%
# Print according to the expected result
print('Jumlah baris dan kolom dari x_train adalah:', X_train.shape,', sedangkan Jumlah baris dan kolom dari y_train adalah:', y_train.shape)
print('Prosentase Churn di data Training adalah:')
print(y_train.value_counts(normalize=True))
print('Jumlah baris dan kolom dari x_test adalah:', X_test.shape,', sedangkan Jumlah baris dan kolom dari y_test adalah:', y_test.shape)
print('Prosentase Churn di data Testing adalah:')
print(y_test.value_counts(normalize=True))
# Out:
# Jumlah baris dan kolom dari x_train adalah: (8101, 17) , sedangkan Jumlah baris dan kolom dari y_train adalah: (8101,)
# Prosentase Churn di data Training adalah:
# 1    0.839526
# 0    0.160474
# Name: status, dtype: float64
# Jumlah baris dan kolom dari x_test adalah: (2026, 17) , sedangkan Jumlah baris dan kolom dari y_test adalah: (2026,)
# Prosentase Churn di data Testing adalah:
# 1    0.838598
# 0    0.161402
# Name: status, dtype: float64

# %%
# normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# **Model Building**
#
# Here are some algorithms that will be tested to determine the best model:
#
# 1.   Logistic Regression
# 2.   Gaussian Naive Bayes
# 3.   Decision Tree
# 4.   Random Forest

# %% [markdown]
# **1. Logistic Regression**

# %%
# train the model
log_model = LogisticRegression().fit(X_train, y_train)
print(log_model)
# Out:
# LogisticRegression()

# %%
# predict data train
y_train_pred_log = log_model.predict(X_train)

# print classification report
print('Classification Report Training Model (Logistic Regression):')
print(classification_report(y_train, y_train_pred_log))
# Out:
# Classification Report Training Model (Logistic Regression):
#               precision    recall  f1-score   support
#
#            0       0.75      0.55      0.64      1300
#            1       0.92      0.96      0.94      6801
#
#     accuracy                           0.90      8101
#    macro avg       0.83      0.76      0.79      8101
# weighted avg       0.89      0.90      0.89      8101

# %%
# form confusion matrix as a dataFrame
confusion_matrix_log = pd.DataFrame((confusion_matrix(y_train, y_train_pred_log)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_log, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Training Model\n(Logistic Regression)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
# predict data test
y_test_pred_log = log_model.predict(X_test)

# print classification report
print('Classification Report Testing Model (Logistic Regression):')
print(classification_report(y_test, y_test_pred_log))
# Out:
# Classification Report Testing Model (Logistic Regression):
#               precision    recall  f1-score   support
#
#            0       0.71      0.49      0.58       327
#            1       0.91      0.96      0.93      1699
#
#     accuracy                           0.89      2026
#    macro avg       0.81      0.73      0.76      2026
# weighted avg       0.88      0.89      0.88      2026

# %%
# form confusion matrix as a dataFrame
confusion_matrix_log = pd.DataFrame((confusion_matrix(y_test, y_test_pred_log)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_log, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Training Model\n(Logistic Regression)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
acc_log_train=round(log_model.score(X_train,y_train)*100,2)
acc_log_test=round(log_model.score(X_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_log_train))
print("Test Accuracy: % {}".format(acc_log_test))
# Out:
# Training Accuracy: % 89.88
# Test Accuracy: % 88.6

# %%
# ROC scores
roc_auc_log = round(roc_auc_score(y_test, y_test_pred_log),4)
print('ROC AUC:', roc_auc_log)
# Out:
# ROC AUC: 0.7258

# %% [markdown]
# **2. Gaussian Naive Bayes**

# %%
# train the model
gnb_model = GaussianNB().fit(X_train, y_train)
print(gnb_model)
# Out:
# GaussianNB()

# %%
# predict data train
y_train_pred_gnb = gnb_model.predict(X_train)

# print classification report
print('Classification Report Training Model (Gaussian Naive Bayes):')
print(classification_report(y_train, y_train_pred_gnb))
# Out:
# Classification Report Training Model (Gaussian Naive Bayes):
#               precision    recall  f1-score   support
#
#            0       0.61      0.60      0.61      1300
#            1       0.92      0.93      0.93      6801
#
#     accuracy                           0.87      8101
#    macro avg       0.77      0.76      0.77      8101
# weighted avg       0.87      0.87      0.87      8101

# %%
# form confusion matrix as a dataFrame
confusion_matrix_gnb = pd.DataFrame((confusion_matrix(y_train, y_train_pred_gnb)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_gnb, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Training Model\n(Gaussian Naive Bayes)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
# predict data test
y_test_pred_gnb = gnb_model.predict(X_test)

# print classification report
print('Classification Report Testing Model (Gaussian Naive Bayes):')
print(classification_report(y_test, y_test_pred_gnb))
# Out:
# Classification Report Testing Model (Gaussian Naive Bayes):
#               precision    recall  f1-score   support
#
#            0       0.60      0.51      0.55       327
#            1       0.91      0.93      0.92      1699
#
#     accuracy                           0.87      2026
#    macro avg       0.75      0.72      0.74      2026
# weighted avg       0.86      0.87      0.86      2026

# %%
# form confusion matrix as a dataFrame
confusion_matrix_gnb = pd.DataFrame((confusion_matrix(y_test, y_test_pred_gnb)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_gnb, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Testing Model\n(Gaussian Naive Bayes)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
acc_nb_train=round(gnb_model.score(X_train,y_train)*100,2)
acc_nb_test=round(gnb_model.score(X_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_nb_train))
print("Test Accuracy: % {}".format(acc_nb_test))
# Out:
# Training Accuracy: % 87.47
# Test Accuracy: % 86.53

# %%
# ROC scores
roc_auc_gnb = round(roc_auc_score(y_test, y_test_pred_gnb),4)
print('ROC AUC:', roc_auc_gnb)
# Out:
# ROC AUC: 0.7221

# %% [markdown]
# **3. Decision Tree**

# %%
# train the model
dt_model = DecisionTreeClassifier().fit(X_train,y_train)
print(dt_model)
# Out:
# DecisionTreeClassifier()

# %%
# predict data train
y_train_pred_dt = dt_model.predict(X_train)

# print classification report
print('Classification Report Training Model (Decision Tree Classifier):')
print(classification_report(y_train, y_train_pred_dt))
# Out:
# Classification Report Training Model (Decision Tree Classifier):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1300
#            1       1.00      1.00      1.00      6801
#
#     accuracy                           1.00      8101
#    macro avg       1.00      1.00      1.00      8101
# weighted avg       1.00      1.00      1.00      8101

# %%
# form confusion matrix as a dataFrame
confusion_matrix_dt = pd.DataFrame((confusion_matrix(y_train, y_train_pred_dt)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_dt, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Training Model\n(Decision Tree Classifier)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
# predict data test
y_test_pred_dt = dt_model.predict(X_test)

# print classification report
print('Classification Report Testing Model (Decision Tree Classifier):')
print(classification_report(y_test, y_test_pred_dt))
# Out:
# Classification Report Testing Model (Decision Tree Classifier):
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76       327
#            1       0.96      0.95      0.95      1699
#
#     accuracy                           0.92      2026
#    macro avg       0.85      0.86      0.86      2026
# weighted avg       0.92      0.92      0.92      2026

# %%
# form confusion matrix as a dataFrame
confusion_matrix_dt = pd.DataFrame((confusion_matrix(y_test, y_test_pred_dt)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_dt, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Testing Model\n(Decision Tree Classifier)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
acc_dt_train=round(dt_model.score(X_train,y_train)*100,2)
acc_dt_test=round(dt_model.score(X_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_dt_train))
print("Test Accuracy: % {}".format(acc_dt_test))
# Out:
# Training Accuracy: % 100.0
# Test Accuracy: % 92.2

# %%
# ROC scores
roc_auc_dt = round(roc_auc_score(y_test, y_test_pred_dt),4)
print('ROC AUC:', roc_auc_dt)
# Out:
# ROC AUC: 0.8621

# %% [markdown]
# **4. Gradient Boosting Classifier**

# %%
gbt_model=GradientBoostingClassifier().fit(X_train,y_train)
print(gbt_model)
# Out:
# GradientBoostingClassifier()

# %%
# Predict data train
y_train_pred_gbt = gbt_model.predict(X_train)
# Print classification report 
print('Classification Report Training Model (Gradient Boosting):')
print(classification_report(y_train,y_train_pred_gbt))
# Out:
# Classification Report Training Model (Gradient Boosting):
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88      1300
#            1       0.97      0.99      0.98      6801
#
#     accuracy                           0.96      8101
#    macro avg       0.95      0.92      0.93      8101
# weighted avg       0.96      0.96      0.96      8101

# %%
# form confusion matrix as a dataFrame
confusion_matrix_gbt = pd.DataFrame((confusion_matrix(y_train, y_train_pred_gbt)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_dt, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Training Model\n(Gradient Boosting Classifier)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
# Predict
y_test_pred_gbt = gbt_model.predict(X_test)
# Print classification report 
print('Classification Report Testing Model (Gradient Boosting):')
print(classification_report(y_test,y_test_pred_gbt))
# Out:
# Classification Report Testing Model (Gradient Boosting):
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85       327
#            1       0.96      0.99      0.97      1699
#
#     accuracy                           0.96      2026
#    macro avg       0.95      0.89      0.91      2026
# weighted avg       0.96      0.96      0.96      2026

# %%
# form confusion matrix as a dataFrame
confusion_matrix_gbt = pd.DataFrame((confusion_matrix(y_test, y_test_pred_gbt)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_dt, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Testing Model\n(Gradient Boosting Classifier)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
acc_gbt_train=round(gbt_model.score(X_train,y_train)*100,2)
acc_gbt_test=round(gbt_model.score(X_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_gbt_train))
print("Test Accuracy: % {}".format(acc_gbt_test))
# Out:
# Training Accuracy: % 96.46
# Test Accuracy: % 95.66

# %%
# ROC scores
roc_auc_gbt = round(roc_auc_score(y_test, y_test_pred_gbt),4)
print('ROC AUC:', roc_auc_gbt)
# Out:
# ROC AUC: 0.8877

# %% [markdown]
# **5. Random Forest**

# %%
# train the model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
print(rf_model)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# predict data train
y_train_pred_rf = rf_model.predict(X_train)

# print classification report
print('Classification Report Training Model (Decision Tree Classifier):')
print(classification_report(y_train, y_train_pred_rf))
# Out:
# Classification Report Training Model (Decision Tree Classifier):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1300
#            1       1.00      1.00      1.00      6801
#
#     accuracy                           1.00      8101
#    macro avg       1.00      1.00      1.00      8101
# weighted avg       1.00      1.00      1.00      8101

# %%
# form confusion matrix as a dataFrame
confusion_matrix_rf = pd.DataFrame((confusion_matrix(y_train, y_train_pred_rf)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_rf, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Training Model\n(Random Forest)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
# predict data test
y_test_pred_rf = rf_model.predict(X_test)
from sklearn.metrics import confusion_matrix, classification_report

# print classification report
print('Classification Report Testing Model (Random Forest Classifier):')
print(classification_report(y_test, y_test_pred_rf))
# Out:
# Classification Report Testing Model (Random Forest Classifier):
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83       327
#            1       0.95      0.99      0.97      1699
#
#     accuracy                           0.95      2026
#    macro avg       0.93      0.87      0.90      2026
# weighted avg       0.95      0.95      0.95      2026

# %%
# form confusion matrix as a dataFrame
confusion_matrix_rf = pd.DataFrame((confusion_matrix(y_test, y_test_pred_rf)), ('Attrited Customer', 'Existing Customer'), ('Attrited\n Customer', 'Existing\n Customer'))

# plot confusion matrix
plt.figure()
heatmap = sns.heatmap(confusion_matrix_rf, annot=True, annot_kws={'size': 14}, fmt='d', cmap='bone_r')
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=0, ha='right', fontsize=14)

plt.title('Confusion Matrix for Testing Model\n(Random Forest)\n', fontsize=18, color='black')
plt.ylabel('True label', fontsize=14)
plt.xlabel('Predicted label', fontsize=14)
plt.show()

# %%
acc_rf_train=round(rf_model.score(X_train,y_train)*100,2)
acc_rf_test=round(rf_model.score(X_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_rf_train))
print("Test Accuracy: % {}".format(acc_rf_test))
# Out:
# Training Accuracy: % 100.0
# Test Accuracy: % 94.87

# %%
# ROC scores
roc_auc_rf = round(roc_auc_score(y_test, y_test_pred_rf),4)
print('ROC AUC:', roc_auc_rf)
# Out:
# ROC AUC: 0.8718

# %%
# important features
importances_rf = pd.Series(rf_model.feature_importances_, index=x.columns).sort_values(ascending=True)

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,10))
fig = importances_rf.plot(kind ='barh', color ='teal')
plt.title('Features Importance Plot\n', fontsize=14)
plt.show()

fig.figure.tight_layout()
fig.figure.savefig('top feature.png')

# %% [markdown]
# # **Model Selection**

# %%
results = pd.DataFrame([["Logistic Regression", 0.8988, 0.886, 0.7258],["Gaussian Naive Bayes", 0.8747, 0.8653, 0.7721],
                       ["Decision Tree", 1, 0.9255, 0.8679],["Gradient Boosting Classifier",0.9646,0.9566,0.8877],["Random Forest", 1, 0.9487, 0.8718]],
                        columns = ["Models", "Training Accuracy Score", "Testing Accuracy Score", "ROC Score"]).reset_index(drop=True)

results.sort_values(by=['Training Accuracy Score', 'Testing Accuracy Score'], ascending=False).style.background_gradient(cmap='mako')
# Out:
# <style type="text/css">
# #T_4a129_row0_col1, #T_4a129_row1_col1, #T_4a129_row2_col2, #T_4a129_row2_col3 {
#   background-color: #def5e5;
#   color: #000000;
# }
# #T_4a129_row0_col2 {
#   background-color: #b0e4c1;
#   color: #000000;
# }
# #T_4a129_row0_col3 {
#   background-color: #a9e1bd;
#   color: #000000;
# }
# #T_4a129_row1_col2 {
#   background-color: #37a8ac;
#   color: #f1f1f1;
# }
# #T_4a129_row1_col3 {
#   background-color: #99ddb6;
#   color: #000000;
# }
# #T_4a129_row2_col1 {
#   background-color: #41b8ad;
#   color: #f1f1f1;
# }
# #T_4a129_row3_col1 {
#   background-color: #372851;
#   color: #f1f1f1;
# }
# #T_4a129_row3_col2 {
#   background-color: #3c3060;
#   color: #f1f1f1;
# }
# #T_4a129_row3_col3, #T_4a129_row4_col1, #T_4a129_row4_col2 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_4a129_row4_col3 {
#   background-color: #413d7b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4a129_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Models</th>
#       <th class="col_heading level0 col1" >Training Accuracy Score</th>
#       <th class="col_heading level0 col2" >Testing Accuracy Score</th>
#       <th class="col_heading level0 col3" >ROC Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a129_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_4a129_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T_4a129_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_4a129_row0_col2" class="data row0 col2" >0.948700</td>
#       <td id="T_4a129_row0_col3" class="data row0 col3" >0.871800</td>
#     </tr>
#     <tr>
#       <th id="T_4a129_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4a129_row1_col0" class="data row1 col0" >Decision Tree</td>
#       <td id="T_4a129_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4a129_row1_col2" class="data row1 col2" >0.925500</td>
#       <td id="T_4a129_row1_col3" class="data row1 col3" >0.867900</td>
#     </tr>
#     <tr>
#       <th id="T_4a129_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4a129_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_4a129_row2_col1" class="data row2 col1" >0.964600</td>
#       <td id="T_4a129_row2_col2" class="data row2 col2" >0.956600</td>
#       <td id="T_4a129_row2_col3" class="data row2 col3" >0.887700</td>
#     </tr>
#     <tr>
#       <th id="T_4a129_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_4a129_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_4a129_row3_col1" class="data row3 col1" >0.898800</td>
#       <td id="T_4a129_row3_col2" class="data row3 col2" >0.886000</td>
#       <td id="T_4a129_row3_col3" class="data row3 col3" >0.725800</td>
#     </tr>
#     <tr>
#       <th id="T_4a129_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_4a129_row4_col0" class="data row4 col0" >Gaussian Naive Bayes</td>
#       <td id="T_4a129_row4_col1" class="data row4 col1" >0.874700</td>
#       <td id="T_4a129_row4_col2" class="data row4 col2" >0.865300</td>
#       <td id="T_4a129_row4_col3" class="data row4 col3" >0.772100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The prediction accuracy of the train and test data in **Random Forest** model has a value that is not much different, it can be said that the model is very good, which is there is no underfitting or overfitting. So the **Random Forest** model was chosen as the best model to predict client’s repayment abilities.

# %% [markdown]
# # **Prediction**

# %% [markdown]
# **Import Dataset**

# %%
df_test = df.copy()

# %%
print('The number of duplication is:', df_test.duplicated().sum())
# there is no duplication
# Out:
# The number of duplication is: 0

# %%
#drop unecessary column
df_test = df_test.drop(columns=['idstatus','Educationid','Maritalid','card_categoryid'])
df.head()
# Out:
#    CLIENTNUM  idstatus             status  Customer_Age  Gender  \
# 0  768805383         1  Existing Customer            45    Male
# 1  818770008         1  Existing Customer            49  Female
# 2  713982108         1  Existing Customer            51    Male
# 3  769911858         1  Existing Customer            40  Female
# 4  709106358         1  Existing Customer            40    Male
#
#    Dependent_count  Educationid Education_Level  Maritalid Marital_Status  \
# 0                3            1     High School          1        Married
# 1                5            2        Graduate          2         Single
# 2                3            2        Graduate          1        Married
# 3                4            1     High School          3        Unknown
# 4                3            3      Uneducated          1        Married
#
#   Income_Category  card_categoryid Card_Category  Months_on_book  \
# 0     $60K - $80K                1          Blue              39
# 1  Less than $40K                1          Blue              44
# 2    $80K - $120K                1          Blue              36
# 3  Less than $40K                1          Blue              34
# 4     $60K - $80K                1          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Trans_Amt  \
# 0         12691                  777            11914             1144
# 1          8256                  864             7392             1291
# 2          3418                    0             3418             1887
# 3          3313                 2517              796             1171
# 4          4716                    0             4716              816
#
#    Total_Trans_Ct  Avg_Utilization_Ratio
# 0              42                  0.061
# 1              33                  0.105
# 2              20                  0.000
# 3              20                  0.760
# 4              28                  0.000

# %%
# check for empty elements
print('Missing values status:', df_test.isnull().values.any())
df_null = pd.DataFrame(df_test.isnull().sum(), columns=['Total Null Values'])
df_null['Percentage'] = (df_null['Total Null Values']/df_test.shape[0])*100
df_null = df_null.sort_values(by=['Percentage'], ascending=False).reset_index()
df_null
# Out:
# Missing values status: False
#                        index  Total Null Values  Percentage
# 0                  CLIENTNUM                  0         0.0
# 1   Total_Relationship_Count                  0         0.0
# 2             Total_Trans_Ct                  0         0.0
# 3            Total_Trans_Amt                  0         0.0
# 4            Avg_Open_To_Buy                  0         0.0
# 5        Total_Revolving_Bal                  0         0.0
# 6               Credit_Limit                  0         0.0
# 7      Contacts_Count_12_mon                  0         0.0
# 8     Months_Inactive_12_mon                  0         0.0
# 9             Months_on_book                  0         0.0
# 10                    status                  0         0.0
# 11             Card_Category                  0         0.0
# 12           Income_Category                  0         0.0
# 13            Marital_Status                  0         0.0
# 14           Education_Level                  0         0.0
# 15           Dependent_count                  0         0.0
# 16                    Gender                  0         0.0
# 17              Customer_Age                  0         0.0
# 18     Avg_Utilization_Ratio                  0         0.0

# %%
df_test.head()
# Out:
#    CLIENTNUM             status  Customer_Age  Gender  Dependent_count  \
# 0  768805383  Existing Customer            45    Male                3
# 1  818770008  Existing Customer            49  Female                5
# 2  713982108  Existing Customer            51    Male                3
# 3  769911858  Existing Customer            40  Female                4
# 4  709106358  Existing Customer            40    Male                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# 1              44                         6                       1
# 2              36                         4                       1
# 3              34                         3                       4
# 4              21                         5                       1
#
#    Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                      3         12691                  777            11914
# 1                      2          8256                  864             7392
# 2                      0          3418                    0             3418
# 3                      1          3313                 2517              796
# 4                      0          4716                    0             4716
#
#    Total_Trans_Amt  Total_Trans_Ct  Avg_Utilization_Ratio
# 0             1144              42                  0.061
# 1             1291              33                  0.105
# 2             1887              20                  0.000
# 3             1171              20                  0.760
# 4              816              28                  0.000

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   status                    10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  int64
#  14  Total_Revolving_Bal       10127 non-null  int64
#  15  Avg_Open_To_Buy           10127 non-null  int64
#  16  Total_Trans_Amt           10127 non-null  int64
#  17  Total_Trans_Ct            10127 non-null  int64
#  18  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(1), int64(12), object(6)
# memory usage: 1.5+ MB

# %%
#Encoding Features
cleaned_df_test = df_test.drop(['CLIENTNUM'], axis=1)

from sklearn.preprocessing import LabelEncoder
#Convert all the non-numeric columns to numerical data types
for column in cleaned_df_test.columns:
    if cleaned_df_test[column].dtype == np.number: continue
    # Perform encoding for each non-numeric column
    cleaned_df_test[column] = LabelEncoder().fit_transform(cleaned_df_test[column])
print(cleaned_df_test.describe())
# Out:
#              status  Customer_Age        Gender  Dependent_count  \
# count  10127.000000  10127.000000  10127.000000     10127.000000
# mean       0.839340     20.325565      0.470919         2.346203
# std        0.367235      8.015598      0.499178         1.298908
# min        0.000000      0.000000      0.000000         0.000000
# 25%        1.000000     15.000000      0.000000         1.000000
# 50%        1.000000     20.000000      0.000000         2.000000
# 75%        1.000000     26.000000      1.000000         3.000000
# max        1.000000     44.000000      1.000000         5.000000
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# count     10127.000000    10127.000000     10127.000000   10127.000000
# mean          3.096574        1.463415         2.863928       0.179816
# std           1.834812        0.737808         1.504700       0.693039
# min           0.000000        0.000000         0.000000       0.000000
# 25%           2.000000        1.000000         2.000000       0.000000
# 50%           3.000000        1.000000         3.000000       0.000000
# 75%           5.000000        2.000000         4.000000       0.000000
# max           6.000000        3.000000         5.000000       3.000000
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# count    10127.000000              10127.000000            10127.000000
# mean        22.928409                  2.812580                2.341167
# std          7.986416                  1.554408                1.010622
# min          0.000000                  0.000000                0.000000
# 25%         18.000000                  2.000000                2.000000
# 50%         23.000000                  3.000000                2.000000
# 75%         27.000000                  4.000000                3.000000
# max         43.000000                  5.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   2650.715809           808.590797
# std                 1.106225   1968.490601           646.358114
# min                 0.000000      0.000000             0.000000
# 25%                 2.000000    932.000000            51.500000
# 50%                 2.000000   2276.000000           814.000000
# 75%                 3.000000   4308.500000          1319.000000
# max                 6.000000   6204.000000          1973.000000
#
#        Avg_Open_To_Buy  Total_Trans_Amt  Total_Trans_Ct  Avg_Utilization_Ratio
# count     10127.000000     10127.000000    10127.000000           10127.000000
# mean       2765.866199      2293.676903       54.857806               0.274894
# std        1984.939480      1303.049259       23.469870               0.275691
# min           0.000000         0.000000        0.000000               0.000000
# 25%        1017.500000      1132.500000       35.000000               0.023000
# 50%        2371.000000      2418.000000       57.000000               0.176000
# 75%        4417.500000      3215.000000       71.000000               0.503000
# max        6669.000000      5032.000000      125.000000               0.999000

# %% [markdown]
# # **Prediction**

# %%
pred_test = cleaned_df_test.drop(['status'], axis=1)

# %%
# lets predict!
predict = pd.Series(rf_model.predict(pred_test), name = 'status').astype(int)
results = pd.concat([df_test['CLIENTNUM'], predict],axis = 1)
results.rename(columns = {'status':'status_pred'}, inplace = True)
results.sort_values(by='status_pred',ascending=True).reset_index(drop=True).head()
# Out:
#    CLIENTNUM  status_pred
# 0  768805383            0
# 1  780038058            0
# 2  822902508            0
# 3  789226683            0
# 4  779681433            0

# %%
results_summary = results.groupby('status_pred').agg(customer_cnt=('CLIENTNUM','count')).reset_index()
results_summary['Status_Meaning'] = ['Attrited Customer','Existing Customer']
results_summary = results_summary[['status_pred','Status_Meaning','customer_cnt']]
print('Churn Customer after predicted :')
results_summary
# Out:
# Churn Customer after predicted :
#    status_pred     Status_Meaning  customer_cnt
# 0            0  Attrited Customer          4833
# 1            1  Existing Customer          5294
